# %%
import pandas as pd
import requests
import warnings
import time
import multiprocessing
import threading
from concurrent.futures import ThreadPoolExecutor
# from google.colab import files
warnings.filterwarnings('ignore', message='Unverified HTTPS request')

# %%
# uploaded = files.upload()
# df = pd.read_csv(io.BytesIO(uploaded[list(uploaded.keys())[0]]))
file_name="chittagong_ipa"
df = pd.read_csv(f"{file_name}.csv")
print(df.head())
print(df.shape)
# Out:
#     words  ipa
# 0  যেত্তে  NaN
# 1    টাইম  NaN
# 2     ফায়  NaN
# 3   এত্তে  NaN
# 4       এ  NaN
# (10892, 2)

# %%
def subset_worker_words(subset):
  print(subset)
  for row in subset.itertuples():
    print(f"Started {row.Index}")
    if pd.notna(row.ipa) and "ERROR" not in row.ipa:
      print("exist")
    else:
      print(f"Started {row.Index} {row.words}")
      # words=row.sentence.split(" ")
      if(False):
        datas=""
        for word in words:
          # url= f"http://ipa.bangla.gov.bd/post_text_bangla_ipa?bangla_ipa={word}"
          url= f"http://127.0.0.1:5000//post_text_bangla_ipa?bangla_ipa={word}"
          response=None
          try:
            response = requests.get (url, verify=False)
            if response and response.status_code == 200:
              data= response.json()
              datas=datas+" "+data["data"][0]
            else:
              datas=datas+" "+"ERROR"
          except:
            print(f"error at{row.Index}:{row.sentence}")
            datas=datas+" "+"ERROR"
        print(f"Ended {row.Index}")
        df.at[row.Index,"ipa"]=datas
      else:
        url = f"http://127.0.0.1:5000//post_text_bangla_ipa?bangla_ipa={row.words}"
        response=None
        try:
          response = requests.get (url, verify=False)
          if response and response.status_code == 200:
            data= response.json()
            df.at[row.Index,"ipa"]=data["data"][0]
            print(f"Ended {row.Index}:{row.words}")
            print(f"{row.Index}:{data['data'][0]}")
          else:
            data= None
        except Exception as e:
          print(e)
          print(f"error at{row.Index}:{row.words}")
    
    # if pd.notna(row.ipa_rangpur) and "ERROR" not in row.ipa_rangpur:
    #   continue
    # print(f"Started {row.Index} {row.Rangpur}")
    # if(False):
    #   datas=""
    #   for word in words:
    #     # url= f"http://ipa.bangla.gov.bd/post_text_bangla_ipa?bangla_ipa={word}"
    #     url= f"http://127.0.0.1:5000//post_text_bangla_ipa?bangla_ipa={word}"
    #     response=None
    #     try:
    #       response = requests.get (url, verify=False)
    #       if response and response.status_code == 200:
    #         data= response.json()
    #         datas=datas+" "+data["data"][0]
    #       else:
    #         datas=datas+" "+"ERROR"
    #     except:
    #       print(f"error at{row.Index}:{row.sentence}")
    #       datas=datas+" "+"ERROR"
    #   print(f"Ended {row.Index}")
    #   df.at[row.Index,"ipa"]=datas
    # else:
    #   url = f"http://127.0.0.1:5000//post_text_bangla_ipa?bangla_ipa={row.Rangpur}"
    #   response=None
    #   try:
    #     response = requests.get (url, verify=False)
    #     if response and response.status_code == 200:
    #       data= response.json()
    #       df.at[row.Index,"ipa_rangpur"]=data["data"][0]
    #       print(f"Ended {row.Index}:{row.Rangpur}")
    #       print(f"{row.Index}:{data['data'][0]}")
    #     else:
    #       data= None
    #   except Exception as e:
    #     print(e)
    #     print(f"error at{row.Index}:{row.Rangpur}")
  # df.to_csv("withIPA.csv",index=False)
  print("Done")
  return

# %%
def subset_worker(subset):
  print(subset)
  for row in subset.itertuples():
    print(f"Started{row.Index}")
    if pd.notna(row.ipa):
      print(f"{row.Index}:{row.ipa}")
      continue
    url = f"http://127.0.0.1:5000//post_text_bangla_ipa?bangla_ipa={row.sentence}"
    response=None
    try:
      response = requests.get (url, verify=False)
      if response and response.status_code == 200:
        data= response.json()
        df.at[row.Index,"ipa"]=data["data"][0]
      else:
        data= None
    except:
      print(f"error at{row.Index}:{row.sentence}")
    print(f"Ended {row.Index}")
    # print(f"{row.Index}:{row.ipa}")
  # df.to_csv("withIPA.csv",index=False)
  print("Done")
  return

# %%
def subset_worker_db(subset):
  for row in subset.itertuples():
    data=call_api(row.word)
    if data:
      print(f"{row.Index}:{data['data'][0]}")
    else:
      print(row.Index)
      print(row.word)
      break

# %%
# threadpool make sure everything is currect before running this cell
i=0;
while(i<6000):
  start=i
  steps=200
  end=i+2000
  subsets=[]
  start_pos=start
  while start<end:
    subsets.append(df.iloc[start:start+steps])
    start=start+steps
  print(subsets)
  pool=ThreadPoolExecutor(len(subsets))
  ws=[]
  for subset in subsets:
    ws.append(pool.submit(subset_worker_words, subset))
  print(pool.shutdown())
  df.to_csv(f"{file_name}_{start_pos}_{end}.csv",index=False)
  i=i+2000
# Out:
# [        words      ipa
# 0      যেত্তে  ɟet̪t̪e
# 1        টাইম   ta͡i̯m
# 2         ফায়     pʰaʲ
# 3       এত্তে   æt̪t̪e
# 4           এ        e
# ..        ...      ...
# 195    হিসেবে      NaN
# 196      উইতি      NaN
# 197       কেন      NaN
# 198      ফোয়া      NaN
# 199  অইয়্যেনে      NaN
#
# [200 rows x 2 columns],             words  ipa
# 200        ক্যানে  NaN
# 201           বইন  NaN
# 202       খইয়্যুম  NaN
# 203         নমুনা  NaN
# 204         আসলেও  NaN
# ..            ...  ...
# 395   পার্মানেন্ট  NaN
# 396           কান  NaN
# 397          গরের  NaN
# 398  স্যার-ম্যামে  NaN
# 399         ওইদিন  NaN
#
# [200 rows x 2 columns],        words  ipa
# 400     খরদে  NaN
# 401     ওইযে  NaN
# 402  সরকারের  NaN
# 403  অনুমোদন  NaN
# 404   রাস্তা  NaN
# ..       ...  ...
# 595  দিয়্যুম  NaN
# 596     শুধু  NaN
# 597   পয়েন্ট  NaN
# 598      তোর  NaN
# 599  পয়েন্টও  NaN
#
# [200 rows x 2 columns],              words  ipa
# 600         আরোকগো  NaN
# 601  নোয়াখাইল্ল্যা  NaN
# 602           আঁরে  NaN
# 603            আমি  NaN
# 604          বাড়িত  NaN
# ..             ...  ...
# 795            বয়স  NaN
# 796           গিয়ই  NaN
# 797         আড়াচলা  NaN
# 798        অসুবিধা  NaN
# 799            তবু  NaN
#
# [200 rows x 2 columns],        words  ipa
# 800     দেখে  NaN
# 801    ডইককা  NaN
# 802     নিজর  NaN
# 803     হাছে  NaN
# 804     টানি  NaN
# ..       ...  ...
# 995  এগারোটা  NaN
# 996     হইতে  NaN
# 997   বারোটা  NaN
# 998     ঠাডা  NaN
# 999   রোইদের  NaN
#
# [200 rows x 2 columns],            words  ipa
# 1000    খেলিয়েনে  NaN
# 1001       গইরতো  NaN
# 1002     ঢুকিতাম  NaN
# 1003      পিরিয়ড  NaN
# 1004     দুইজ্জা  NaN
# ...          ...  ...
# 1195        সৈকত  NaN
# 1196  খোনোমিক্কে  NaN
# 1197       দেহির  NaN
# 1198       ফারের  NaN
# 1199      সাইবার  NaN
#
# [200 rows x 2 columns],             words  ipa
# 1200          বিচ  NaN
# 1201    কেন্দ্রীক  NaN
# 1202  হোটেল-মোটেল  NaN
# 1203        বিশাল  NaN
# 1204      পরিমাণে  NaN
# ...           ...  ...
# 1395     রেসপেক্ট  NaN
# 1396      সম্মানর  NaN
# 1397   কক্সবাজারত  NaN
# 1398         অওয়া  NaN
# 1399     বেয়াককিন  NaN
#
# [200 rows x 2 columns],         words  ipa
# 1400   অসংখ্য  NaN
# 1401   বিজড়িত  NaN
# 1402      শহর  NaN
# 1403  পৃথিবীত  NaN
# 1404   যেইডেই  NaN
# ...       ...  ...
# 1595    খইতাম  NaN
# 1596     ফেলো  NaN
# 1597  নিয়্যাত  NaN
# 1598  গইরগিলা  NaN
# 1599    ফেলাও  NaN
#
# [200 rows x 2 columns],             words  ipa
# 1600      কনফিউশন  NaN
# 1601      মাঝখানে  NaN
# 1602      ফরকীয়ার  NaN
# 1603         খইবে  NaN
# 1604       খইয়্যো  NaN
# ...           ...  ...
# 1795  গ্রামাঞ্চলে  NaN
# 1796   গোলা-টোলার  NaN
# 1797  দারগো-টারগো  NaN
# 1798         রাহে  NaN
# 1799         ইবেত  NaN
#
# [200 rows x 2 columns],          words  ipa
# 1800     ছাদেত  NaN
# 1801     টাদেত  NaN
# 1802       উডি  NaN
# 1803   ধান-টান  NaN
# 1804   ফুয়্যাত  NaN
# ...        ...  ...
# 1995  এইদিন্যা  NaN
# 1996   খোনরখমে  NaN
# 1997     জামিন  NaN
# 1998   ফাইয়্যি  NaN
# 1999     বিদেশ  NaN
#
# [200 rows x 2 columns]]
#         words      ipa
# 0      যেত্তে  ɟet̪t̪e
# 1        টাইম   ta͡i̯m
# 2         ফায়     pʰaʲ
# 3       এত্তে   æt̪t̪e
# 4           এ        e
# ..        ...      ...
# 195    হিসেবে      NaN
# 196      উইতি      NaN
# 197       কেন      NaN
# 198      ফোয়া      NaN
# 199  অইয়্যেনে      NaN
#
# [200 rows x 2 columns]
# Started 0
# exist
# Started 1
# exist
# Started 2
# exist
# Started 3
# exist
# Started 4
# exist
# Started 5
# exist
# Started 6
# exist
# Started 7
# exist
# Started 8
# exist
# Started 9
# exist
# Started 10
# exist
# Started 11
# exist
# Started 12
# exist
# Started 13
# exist
# Started 14
# exist
# Started 15
# exist
# Started 16
# exist
# Started 17
# exist
# Started 18
# exist
# Started 19
# exist
# Started 20
# exist
# Started 21
# exist
# Started 22
# exist
# Started 23
# exist
# Started 24
# exist
# Started 25
# exist
# Started 26
# exist
# Started 27
# exist
# Started 28
# exist
# Started 29
# exist
# Started 30
# exist
# Started 31
# exist
# Started 32
# exist
# Started 33
# exist
# Started 34
# exist
# Started 35
# exist
# Started 36
# exist
# Started 37
# exist
# Started 38
# exist
# Started 39
# exist
# Started 40
# exist
# Started 41
# exist
# Started 42
# exist
# Started 43
# exist
# Started 44
# exist
# Started 45
# exist
# Started 46
# exist
# Started 47
# exist
# Started 48
# exist
# Started 49
# exist
# Started 50
# exist
# Started 51
# exist
# Started 52
# exist
# Started 53
# exist
# Started 54
# exist
# Started 55
# exist
# Started 56
# exist
# Started 57
# exist
# Started 58
# exist
# Started 59
# exist
# Started 60
# Started 60 আঁরার
#             words  ipa
# 200        ক্যানে  NaN
# 201           বইন  NaN
# 202       খইয়্যুম  NaN
# 203         নমুনা  NaN
# 204         আসলেও  NaN
# ..            ...  ...
# 395   পার্মানেন্ট  NaN
# 396           কান  NaN
# 397          গরের  NaN
# 398  স্যার-ম্যামে  NaN
# 399         ওইদিন  NaN
#
# [200 rows x 2 columns]
# Started 200
# Started 200 ক্যানে
#        words  ipa
# 400     খরদে  NaN
# 401     ওইযে  NaN
# 402  সরকারের  NaN
# 403  অনুমোদন  NaN
# 404   রাস্তা  NaN
# ..       ...  ...
# 595  দিয়্যুম  NaN
# 596     শুধু  NaN
# 597   পয়েন্ট  NaN
# 598      তোর  NaN
# 599  পয়েন্টও  NaN
#
# [200 rows x 2 columns]
# Started 400
# Started 400 খরদে
#              words  ipa
# 600         আরোকগো  NaN
# 601  নোয়াখাইল্ল্যা  NaN
# 602           আঁরে  NaN
# 603            আমি  NaN
# 604          বাড়িত  NaN
# ..             ...  ...
# 795            বয়স  NaN
# 796           গিয়ই  NaN
# 797         আড়াচলা  NaN
# 798        অসুবিধা  NaN
# 799            তবু  NaN
#
# [200 rows x 2 columns]
# Started 600
# Started 600 আরোকগো
#        words  ipa
# 800     দেখে  NaN
# 801    ডইককা  NaN
# 802     নিজর  NaN
# 803     হাছে  NaN
# 804     টানি  NaN
# ..       ...  ...
# 995  এগারোটা  NaN
# 996     হইতে  NaN
# 997   বারোটা  NaN
# 998     ঠাডা  NaN
# 999   রোইদের  NaN
#
# [200 rows x 2 columns]
# Started 800
# Started 800 দেখে
#            words  ipa
# 1000    খেলিয়েনে  NaN
# 1001       গইরতো  NaN
# 1002     ঢুকিতাম  NaN
# 1003      পিরিয়ড  NaN
# 1004     দুইজ্জা  NaN
# ...          ...  ...
# 1195        সৈকত  NaN
# 1196  খোনোমিক্কে  NaN
# 1197       দেহির  NaN
# 1198       ফারের  NaN
# 1199      সাইবার  NaN
#
# [200 rows x 2 columns]
# Started 1000
# Started 1000 খেলিয়েনে
# Ended 60:আঁরার
# 60:ãrar
# Started 61
# Started 61 সিআর
# Ended 600:আরোকগো
# 600:arokgo
# Started 601
# Started 601 নোয়াখাইল্ল্যা
#             words  ipa
# 1200          বিচ  NaN
# 1201    কেন্দ্রীক  NaN
# 1202  হোটেল-মোটেল  NaN
# 1203        বিশাল  NaN
# 1204      পরিমাণে  NaN
# ...           ...  ...
# 1395     রেসপেক্ট  NaN
# 1396      সম্মানর  NaN
# 1397   কক্সবাজারত  NaN
# 1398         অওয়া  NaN
# 1399     বেয়াককিন  NaN
#
# [200 rows x 2 columns]
# Started 1200
# Started 1200 বিচ
#         words  ipa
# 1400   অসংখ্য  NaN
# 1401   বিজড়িত  NaN
# 1402      শহর  NaN
# 1403  পৃথিবীত  NaN
# 1404   যেইডেই  NaN
# ...       ...  ...
# 1595    খইতাম  NaN
# 1596     ফেলো  NaN
# 1597  নিয়্যাত  NaN
# 1598  গইরগিলা  NaN
# 1599    ফেলাও  NaN
#
# [200 rows x 2 columns]
# Started 1400
# Started 1400 অসংখ্য
# Ended 61:সিআর
# 61:si͡a̯r
# Started 62
# Started 62 এইগিন
#             words  ipa
# 1600      কনফিউশন  NaN
# 1601      মাঝখানে  NaN
# 1602      ফরকীয়ার  NaN
# 1603         খইবে  NaN
# 1604       খইয়্যো  NaN
# ...           ...  ...
# 1795  গ্রামাঞ্চলে  NaN
# 1796   গোলা-টোলার  NaN
# 1797  দারগো-টারগো  NaN
# 1798         রাহে  NaN
# 1799         ইবেত  NaN
#
# [200 rows x 2 columns]
# Started 1600
# Started 1600 কনফিউশন
#          words  ipa
# 1800     ছাদেত  NaN
# 1801     টাদেত  NaN
# 1802       উডি  NaN
# 1803   ধান-টান  NaN
# 1804   ফুয়্যাত  NaN
# ...        ...  ...
# 1995  এইদিন্যা  NaN
# 1996   খোনরখমে  NaN
# 1997     জামিন  NaN
# 1998   ফাইয়্যি  NaN
# 1999     বিদেশ  NaN
#
# [200 rows x 2 columns]
# Started 1800
# Started 1800 ছাদেত
# Ended 601:নোয়াখাইল্ল্যা
# 601:noʷakʰa͡i̯llæ
# Started 602
# Started 602 আঁরে
# Ended 1200:বিচ
# 1200:bic
# Started 1201
# Started 1201 কেন্দ্রীক
# Ended 62:এইগিন
# 62:e͡i̯gin
# Started 63
# Started 63 ক্লাস
# Ended 63:ক্লাস
# 63:klas
# Started 64
# Started 64 এটেন্ড
# Ended 64:এটেন্ড
# 64:etend
# Started 65
# Started 65 ইয়্যানই
# Ended 65:ইয়্যানই
# 65:iʲani
# Started 66
# Started 66 ইয়্যিম
# Ended 66:ইয়্যিম
# 66:ikim
# Started 67
# Started 67 আইসতু
# Ended 67:আইসতু
# 67:a͡i̯ʃt̪u
# Started 68
# Started 68 চায়
# Ended 68:চায়
# 68:caʲ
# Started 69
# Started 69 খাম
# Ended 69:খাম
# 69:kʰam
# Started 70
# Started 70 ঘাড়র
# Ended 70:ঘাড়র
# 70:gʱaɽor
# Started 71
# Started 71 উরদি
# Ended 71:উরদি
# 71:urd̪i
# Started 72
# Started 72 চাপাই
# Ended 72:চাপাই
# 72:capa͡i̯
# Started 73
# Started 73 দেয়
# Ended 73:দেয়
# 73:d̪eʲ
# Started 74
# Started 74 খতা
# Ended 74:খতা
# 74:kʰɔt̪a
# Started 75
# Started 75 অইয়্যেদে
# Ended 75:অইয়্যেদে
# 75:ɔ͡i̯kd̪ʱed̪e
# Started 76
# Started 76 আঁরা
# Ended 76:আঁরা
# 76:ãra
# Started 77
# Started 77 ইয়্যিন
# Ended 77:ইয়্যিন
# 77:ikin
# Started 78
# Started 78 জানি
# Ended 78:জানি
# 78:ɟani
# Started 79
# Started 79 টাম
# Ended 79:টাম
# 79:tam
# Started 80
# Started 80 কেইল্লা
# Ended 80:কেইল্লা
# 80:ke͡i̯lla
# Started 81
# Started 81 গরি
# Ended 81:গরি
# 81:gori
# Started 82
# Started 82 কী
# Ended 82:কী
# 82:ki
# Started 83
# Started 83 আলাদা
# Ended 83:আলাদা
# 83:alad̪a
# Started 84
# Started 84 স্যারের
# Ended 84:স্যারের
# 84:særer
# Started 85
# Started 85 তুন
# Ended 85:তুন
# 85:t̪un
# Started 86
# Started 86 যাইয়েরে
# Ended 86:যাইয়েরে
# 86:ɟa͡i̯ʲere
# Started 87
# Started 87 ইয়্যান
# Ended 87:ইয়্যান
# 87:iʲæn
# Started 88
# Started 88 কালেক্ট
# Ended 88:কালেক্ট
# 88:kalektɔ
# Started 89
# Started 89 গরিবু
# Ended 800:দেখে
# 800:d̪ekʰe
# Started 801
# Started 801 ডইককা
# Ended 801:ডইককা
# 801:do͡i̯kka
# Started 802
# Started 802 নিজর
# Ended 802:নিজর
# 802:niɟɔr
# Started 803
# Started 803 হাছে
# Ended 803:হাছে
# 803:hacʰe
# Started 804
# Started 804 টানি
# Ended 804:টানি
# 804:tani
# Started 805
# Started 805 প্রাইমারি
# Ended 805:প্রাইমারি
# 805:pra͡i̯mari
# Started 806
# Started 806 অইয়ে
# Ended 806:অইয়ে
# 806:ɔ͡i̯ʲe
# Started 807
# Started 807 পি
# Ended 807:পি
# 807:pi
# Started 808
# Started 808 টি
# Ended 808:টি
# 808:ti
# Started 809
# Started 809 আইড
# Ended 809:আইড
# 809:a͡i̯d
# Started 810
# Started 810 টিচার্স
# Ended 810:টিচার্স
# 810:ticars
# Started 811
# Started 811 ট্রেনিং
# Ended 811:ট্রেনিং
# 811:treniŋ
# Started 812
# Started 812 ইনস্টিটিউট
# Ended 812:ইনস্টিটিউট
# 812:inoʃtiti͡u̯t
# Started 813
# Started 813 ইয়ানরে
# Ended 602:আঁরে
# 602:ãre
# Started 603
# Started 603 আমি
# Ended 603:আমি
# 603:ami
# Started 604
# Started 604 বাড়িত
# Ended 604:বাড়িত
# 604:baɽit̪o
# Started 605
# Started 605 আসছি
# Ended 605:আসছি
# 605:aʃcʰi
# Started 606
# Started 606 গেইয়্যস
# Ended 606:গেইয়্যস
# 606:ge͡i̯ʲt̪oʃ
# Started 607
# Started 607 খোনো
# Ended 607:খোনো
# 607:kʰono
# Started 608
# Started 608 বিষয়
# Ended 608:বিষয়
# 608:biʃɔʲ
# Started 609
# Started 609 তোরে
# Ended 609:তোরে
# 609:t̪ore
# Started 610
# Started 610 খইদে
# Ended 610:খইদে
# 610:kʰo͡i̯d̪e
# Started 611
# Started 611 সপ্তাহ
# Ended 611:সপ্তাহ
# 611:ʃɔpt̪aho
# Started 612
# Started 612 একদিন
# Ended 612:একদিন
# 612:ækd̪in
# Started 613
# Started 613 আইসসি
# Ended 400:খরদে
# 400:kʰɔrd̪e
# Started 401
# Started 401 ওইযে
# Ended 401:ওইযে
# 401:o͡i̯ɟe
# Started 402
# Started 402 সরকারের
# Ended 402:সরকারের
# 402:ʃɔrkarer
# Started 403
# Started 403 অনুমোদন
# Ended 403:অনুমোদন
# 403:onumod̪on
# Started 404
# Started 404 রাস্তা
# Ended 404:রাস্তা
# 404:rast̪a
# Started 405
# Started 405 গেইয়্যে
# Ended 405:গেইয়্যে
# 405:ge͡i̯ʲt̪e
# Started 406
# Started 406 রোড
# Ended 406:রোড
# 406:rod
# Started 407
# Started 407 ব্রিজ
# Ended 407:ব্রিজ
# 407:briɟ
# Started 408
# Started 408 ফ্যারা
# Ended 408:ফ্যারা
# 408:pʰæra
# Started 409
# Started 409 এহতেরলাই
# Ended 409:এহতেরলাই
# 409:ehot̪erla͡i̯
# Started 410
# Started 410 এতদিন
# Ended 410:এতদিন
# 410:æt̪od̪in
# Started 411
# Started 411 স্থগিত
# Ended 411:স্থগিত
# 411:st̪ʰogit̪o
# Started 412
# Started 412 রাইকখি
# Ended 412:রাইকখি
# 412:ra͡i̯kkʰi
# Started 413
# Started 413 গরিবারলাই
# Ended 1800:ছাদেত
# 1800:cʰad̪et̪
# Started 1801
# Started 1801 টাদেত
# Ended 89:গরিবু
# 89:goribu
# Started 90
# Started 90 আঁরারে
# Ended 90:আঁরারে
# 90:ãrare
# Started 91
# Started 91 বাজাই
# Ended 91:বাজাই
# 91:baɟa͡i̯
# Started 92
# Started 92 দিয়্যেনে
# Ended 92:দিয়্যেনে
# 92:d̪iklene
# Started 93
# Started 93 যায়গুই
# Ended 93:যায়গুই
# 93:ɟaʲgu͡i̯
# Started 94
# Started 94 ফিছাই
# Ended 94:ফিছাই
# 94:pʰicʰa͡i̯
# Started 95
# Started 95 যিগুই
# Ended 95:যিগুই
# 95:ɟigu͡i̯
# Started 96
# Started 96 বি
# Ended 96:বি
# 96:bi
# Started 97
# Started 97 সেকশনের
# Ended 97:সেকশনের
# 97:ʃekʃoner
# Started 98
# Started 98 সেকশন
# Ended 98:সেকশন
# 98:ʃekʃon
# Started 99
# Started 99 দেহি
# Ended 99:দেহি
# 99:d̪ehi
# Started 100
# Started 100 যাইয়্যেনে
# Ended 200:ক্যানে
# 200:kæne
# Started 201
# Started 201 বইন
# Ended 201:বইন
# 201:bo͡i̯n
# Started 202
# Started 202 খইয়্যুম
# Ended 202:খইয়্যুম
# 202:kʰo͡i̯ʲd̪ʱum
# Started 203
# Started 203 নমুনা
# Ended 203:নমুনা
# 203:nomuna
# Started 204
# Started 204 আসলেও
# Ended 204:আসলেও
# 204:aʃole͡o̯
# Started 205
# Started 205 ইয়্যুনরে
# Ended 205:ইয়্যুনরে
# 205:iʲunɔre
# Started 206
# Started 206 ধরিয়েনে
# Ended 206:ধরিয়েনে
# 206:d̪ʱoriʲene
# Started 207
# Started 207 জাদুঘরে
# Ended 207:জাদুঘরে
# 207:ɟad̪ugʱɔre
# Started 208
# Started 208 রাহন
# Ended 208:রাহন
# 208:rahon
# Started 209
# Started 209 যাইবু
# Ended 209:যাইবু
# 209:ɟa͡i̯bu
# Started 210
# Started 210 অইলে
# Ended 210:অইলে
# 210:æ͡i̯le
# Started 211
# Started 211 ধ্বংস
# Ended 211:ধ্বংস
# 211:d̪ʱɔŋʃo
# Started 212
# Started 212 কিল্লাই
# Ended 1400:অসংখ্য
# 1400:ɔʃɔŋkʰkʰo
# Started 1401
# Started 1401 বিজড়িত
# Ended 1401:বিজড়িত
# 1401:biɟoɽit̪o
# Started 1402
# Started 1402 শহর
# Ended 1402:শহর
# 1402:ʃɔhor
# Started 1403
# Started 1403 পৃথিবীত
# Ended 1600:কনফিউশন
# 1600:konpʰi͡u̯ʃon
# Started 1601
# Started 1601 মাঝখানে
# Ended 1601:মাঝখানে
# 1601:maɟʱkʰane
# Started 1602
# Started 1602 ফরকীয়ার
# Ended 1000:খেলিয়েনে
# 1000:kʰeliʲene
# Started 1001
# Started 1001 গইরতো
# Ended 613:আইসসি
# 613:a͡i̯ssi
# Started 614
# Started 614 তিনটা
# Ended 614:তিনটা
# 614:t̪inta
# Started 615
# Started 615 ফুলিয়্যেনে
# Ended 1201:কেন্দ্রীক
# 1201:kend̪rik
# Started 1202
# Started 1202 হোটেল-মোটেল
# Ended 813:ইয়ানরে
# 813:iʲanre
# Started 814
# Started 814 ইংরেজিত
# Ended 814:ইংরেজিত
# 814:iŋreɟit̪o
# Started 815
# Started 815 হওয়া
# Ended 815:হওয়া
# 815:hoʷa
# Started 816
# Started 816 এড়েও
# Ended 816:এড়েও
# 816:eɽe͡o̯
# Started 817
# Started 817 সুমধুর
# Ended 817:সুমধুর
# 817:ʃumd̪ʱur
# Started 818
# Started 818 স্মৃতি
# Ended 818:স্মৃতি
# 818:srit̪i
# Started 819
# Started 819 পড়ালেখার
# Ended 1801:টাদেত
# 1801:tad̪et̪
# Started 1802
# Started 1802 উডি
# Ended 819:পড়ালেখার
# 819:pɔɽalekʰar
# Started 820
# Started 820 পাশাপাশি
# Ended 1802:উডি
# 1802:udi
# Started 1803
# Started 1803 ধান-টান
# Ended 1403:পৃথিবীত
# 1403:prit̪ʰibit̪o
# Started 1404
# Started 1404 যেইডেই
# Ended 1001:গইরতো
# 1001:girot̪o
# Started 1002
# Started 1002 ঢুকিতাম
# Ended 212:কিল্লাই
# 212:killa͡i̯
# Started 213
# Started 213 ইতার
# Ended 213:ইতার
# 213:it̪ar
# Started 214
# Started 214 হাতে
# Ended 214:হাতে
# 214:hat̪e
# Started 215
# Started 215 ফুরা
# Ended 215:ফুরা
# 215:pʰura
# Started 216
# Started 216 ডিপেন্ড
# Ended 216:ডিপেন্ড
# 216:dipend
# Started 217
# Started 217 আরকি
# Ended 217:আরকি
# 217:arɔki
# Started 218
# Started 218 সিআরে
# Ended 218:সিআরে
# 218:si͡a̯re
# Started 219
# Started 219 তসেমিস্টার
# Ended 219:তসেমিস্টার
# 219:t̪ɔʃemistar
# Started 220
# Started 220 শেষ
# Ended 220:শেষ
# 220:ʃeʃ
# Started 221
# Started 221 নতুন
# Ended 221:নতুন
# 221:not̪un
# Started 222
# Started 222 সেমিস্টার
# Ended 222:সেমিস্টার
# 222:ʃemistar
# Started 223
# Started 223 অইবো
# Ended 223:অইবো
# 223:ɔ͡i̯bo
# Started 224
# Started 224 দিবো
# Ended 224:দিবো
# 224:d̪ibo
# Started 225
# Started 225 ঠিক
# Ended 225:ঠিক
# 225:tʰik
# Started 226
# Started 226 খইরদি
# Ended 226:খইরদি
# 226:kʰo͡i̯rd̪i
# Started 227
# Started 227 যাতে
# Ended 227:যাতে
# 227:ɟat̪e
# Started 228
# Started 228 জিন্দেগীত
# Ended 228:জিন্দেগীত
# 228:ɟind̪egit̪
# Started 229
# Started 229 ত্যানাত্যানা
# Ended 229:ত্যানাত্যানা
# 229:t̪ænat̪t̪ana
# Started 230
# Started 230 বানাই
# Ended 230:বানাই
# 230:bana͡i̯
# Started 231
# Started 231 ফালাইয়্যে
# Ended 231:ফালাইয়্যে
# 231:pʰala͡i̯ʲt̪e
# Started 232
# Started 232 দিয়্যি
# Ended 232:দিয়্যি
# 232:d̪ikd̪i
# Started 233
# Started 233 না
# Ended 233:না
# 233:na
# Started 234
# Started 234 এইল্লাত
# Ended 234:এইল্লাত
# 234:e͡i̯llat̪o
# Started 235
# Started 235 তোঁয়ারা
# Ended 235:তোঁয়ারা
# 235:t̪õʷara
# Started 236
# Started 236 খইবা
# Ended 236:খইবা
# 236:kʰo͡i̯ba
# Started 237
# Started 237 লটারি
# Ended 237:লটারি
# 237:lɔtari
# Started 238
# Started 238 সিস্টেমে
# Ended 238:সিস্টেমে
# 238:ʃisteme
# Started 239
# Started 239 যারার
# Ended 239:যারার
# 239:ɟarar
# Started 240
# Started 240 ফরের
# Ended 240:ফরের
# 240:pʰɔrer
# Started 241
# Started 241 সাইরদে
# Ended 241:সাইরদে
# 241:sa͡i̯rd̪e
# Started 242
# Started 242 ফিছের
# Ended 242:ফিছের
# 242:pʰicʰer
# Started 243
# Started 243 দেহেন
# Ended 243:দেহেন
# 243:d̪ehen
# Started 244
# Started 244 অনে
# Ended 244:অনে
# 244:ɔne
# Started 245
# Started 245 গরন
# Ended 413:গরিবারলাই
# 413:goribarla͡i̯
# Started 414
# Started 414 ক্যাম্পাস
# Ended 245:গরন
# 245:gɔron
# Started 246
# Started 246 দওন
# Ended 246:দওন
# 246:d̪ɔ͡o̯n
# Started 247
# Started 247 বাছাই
# Ended 247:বাছাই
# 247:bacʰa͡i̯
# Started 248
# Started 248 লই
# Ended 248:লই
# 248:lɔ͡i̯
# Started 249
# Started 249 কিতারে
# Ended 249:কিতারে
# 249:kit̪are
# Started 250
# Started 250 দেওন
# Ended 250:দেওন
# 250:d̪æ͡o̯n
# Started 251
# Started 251 কিতে
# Ended 251:কিতে
# 251:kit̪e
# Started 252
# Started 252 ভালা
# Ended 252:ভালা
# 252:bʱala
# Started 253
# Started 253 গরিবো
# Ended 1602:ফরকীয়ার
# 1602:pʰɔrkiʲar
# Started 1603
# Started 1603 খইবে
# Ended 100:যাইয়্যেনে
# 100:ɟa͡i̯ʲd̪ʱene
# Started 101
# Started 101 আরও
# Ended 101:আরও
# 101:arɔ͡o̯
# Started 102
# Started 102 চাইর
# Ended 102:চাইর
# 102:ca͡i̯r
# Started 103
# Started 103 ধাপ
# Ended 103:ধাপ
# 103:d̪ʱap
# Started 104
# Started 104 ফরা
# Ended 104:ফরা
# 104:pʰɔra
# Started 105
# Started 105 আগাই
# Ended 105:আগাই
# 105:aga͡i̯
# Started 106
# Started 106 গেইয়্যেগই
# Ended 1803:ধান-টান
# 1803:d̪ʱan-tan
# Started 1804
# Started 1804 ফুয়্যাত
# Ended 1603:খইবে
# 1603:kʰo͡i̯be
# Started 1604
# Started 1604 খইয়্যো
# Ended 820:পাশাপাশি
# 820:paʃapaʃi
# Started 821
# Started 821 খেলাধুলা
# Ended 821:খেলাধুলা
# 821:kʰelad̪ʱula
# Started 822
# Started 822 বান্ধব
# Ended 822:বান্ধব
# 822:band̪ʱob
# Started 823
# Started 823 যিন
# Ended 253:গরিবো
# 253:goribo
# Started 254
# Started 254 ইবে
# Ended 254:ইবে
# 254:ibe
# Started 255
# Started 255 খই
# Ended 255:খই
# 255:kʰo͡i̯
# Started 256
# Started 256 সাইততারো
# Ended 1404:যেইডেই
# 1404:ɟe͡i̯de͡i̯
# Started 1405
# Started 1405 যাইনা
# Ended 1405:যাইনা
# 1405:ɟa͡i̯na
# Started 1406
# Started 1406 জীবিকার
# Ended 1406:জীবিকার
# 1406:ɟibikar
# Started 1407
# Started 1407 তাগিদে
# Ended 1407:তাগিদে
# 1407:t̪agid̪e
# Started 1408
# Started 1408 কক্সবাজাররে
# Ended 1202:হোটেল-মোটেল
# 1202:hotel-motel
# Started 1203
# Started 1203 বিশাল
# Ended 1203:বিশাল
# 1203:biʃal
# Started 1204
# Started 1204 পরিমাণে
# Ended 1204:পরিমাণে
# 1204:porimane
# Started 1205
# Started 1205 লাভ
# Ended 1205:লাভ
# 1205:labʱ
# Started 1206
# Started 1206 তুলে
# Ended 1206:তুলে
# 1206:t̪ule
# Started 1207
# Started 1207 সরকারর
# Ended 615:ফুলিয়্যেনে
# 615:pʰuliʲlene
# Started 616
# Started 616 অর্নবে
# Ended 616:অর্নবে
# 616:ɔrnobe
# Started 617
# Started 617 ফারেরদে
# Ended 617:ফারেরদে
# 617:pʰarerd̪e
# Started 618
# Started 618 গিলিয়ারে
# Ended 618:গিলিয়ারে
# 618:giliʲare
# Started 619
# Started 619 ফালাইবু
# Ended 1002:ঢুকিতাম
# 1002:dʱukit̪am
# Started 1003
# Started 1003 পিরিয়ড
# Ended 1003:পিরিয়ড
# 1003:piriʲod
# Started 1004
# Started 1004 দুইজ্জা
# Ended 823:যিন
# 823:ɟin
# Started 824
# Started 824 এককু
# Ended 824:এককু
# 824:ækku
# Started 825
# Started 825 ফুয়াতি
# Ended 825:ফুয়াতি
# 825:pʰuʲat̪i
# Started 826
# Started 826 বইলে
# Ended 414:ক্যাম্পাস
# 414:kæmpaʃ
# Started 415
# Started 415 আসল
# Ended 415:আসল
# 415:aʃol
# Started 416
# Started 416 নয়
# Ended 416:নয়
# 416:nɔʲ
# Started 417
# Started 417 আবাসিকর
# Ended 417:আবাসিকর
# 417:abaʃikɔr
# Started 418
# Started 418 যেততে
# Ended 418:যেততে
# 418:ɟet̪t̪e
# Started 419
# Started 419 পরিপূর্ণভাবে
# Ended 419:পরিপূর্ণভাবে
# 419:poripurnobʱabe
# Started 420
# Started 420 যাইবো
# Ended 420:যাইবো
# 420:ɟa͡i̯bo
# Started 421
# Started 421 তারফর
# Ended 421:তারফর
# 421:t̪arpʰɔr
# Started 422
# Started 422 আরারে
# Ended 422:আরারে
# 422:arare
# Started 423
# Started 423 ট্রান্সফার
# Ended 423:ট্রান্সফার
# 423:transpʰar
# Started 424
# Started 424 হবে
# Ended 424:হবে
# 424:hɔbe
# Started 425
# Started 425 সালত
# Ended 425:সালত
# 425:salɔt̪
# Started 426
# Started 426 ইয়ানততু
# Ended 426:ইয়ানততু
# 426:iʲant̪ot̪u
# Started 427
# Started 427 উনির
# Ended 1804:ফুয়্যাত
# 1804:pʰukɟat̪o
# Started 1805
# Started 1805 দিই
# Ended 1805:দিই
# 1805:d̪i͡i̯
# Started 1806
# Started 1806 মা-বোন
# Ended 1806:মা-বোন
# 1806:ma-bon
# Started 1807
# Started 1807 জিরায়-টিরায়
# Ended 106:গেইয়্যেগই
# 106:ge͡i̯ʲegi
# Started 107
# Started 107 এডে
# Ended 107:এডে
# 107:ede
# Started 108
# Started 108 তে
# Ended 108:তে
# 108:t̪e
# Started 109
# Started 109 দিনের
# Ended 109:দিনের
# 109:d̪iner
# Started 110
# Started 110 আগের
# Ended 110:আগের
# 110:ager
# Started 111
# Started 111 আইজু
# Ended 1604:খইয়্যো
# 1604:kʰo͡i̯ʲd̪ʱo
# Started 1605
# Started 1605 একজন
# Ended 1605:একজন
# 1605:ækɟon
# Started 1606
# Started 1606 ফ্রেন্ড
# Ended 1606:ফ্রেন্ড
# 1606:pʰrend
# Started 1607
# Started 1607 লম্বা
# Ended 1607:লম্বা
# 1607:lɔmba
# Started 1608
# Started 1608 খইয়্যু
# Ended 1207:সরকারর
# 1207:ʃɔrkaror
# Started 1208
# Started 1208 প্রচুর
# Ended 1208:প্রচুর
# 1208:procur
# Started 1209
# Started 1209 রাজস্বও
# Ended 826:বইলে
# 826:bo͡i̯le
# Started 827
# Started 827 রোমন্থন
# Ended 827:রোমন্থন
# 827:romont̪ʰɔn
# Started 828
# Started 828 হাসাহাসি
# Ended 828:হাসাহাসি
# 828:haʃahaʃi
# Started 829
# Started 829 এককালে
# Ended 829:এককালে
# 829:ækkale
# Started 830
# Started 830 ইন
# Ended 830:ইন
# 830:in
# Started 831
# Started 831 গইজঝি
# Ended 256:সাইততারো
# 256:sa͡i̯t̪ɔt̪aro
# Started 257
# Started 257 বেয়াকে
# Ended 257:বেয়াকে
# 257:beʲake
# Started 258
# Started 258 খইয়্যেদে
# Ended 258:খইয়্যেদে
# 258:kʰo͡i̯ʲd̪ʱed̪e
# Started 259
# Started 259 নাকি
# Ended 259:নাকি
# 259:naki
# Started 260
# Started 260 ক্লাসরুম
# Ended 260:ক্লাসরুম
# 260:klaʃrum
# Started 261
# Started 261 ম্যানটেইন
# Ended 261:ম্যানটেইন
# 261:mænte͡i̯n
# Started 262
# Started 262 অ
# Ended 262:অ
# 262:ɔ
# Started 263
# Started 263 সিআরই
# Ended 263:সিআরই
# 263:si͡a̯ri
# Started 264
# Started 264 উলটা
# Ended 264:উলটা
# 264:ulta
# Started 265
# Started 265 পরিমাণ
# Ended 265:পরিমাণ
# 265:poriman
# Started 266
# Started 266 পরিশ্রম
# Ended 427:উনির
# 427:unir
# Started 428
# Started 428 পাঁচ
# Ended 266:পরিশ্রম
# 266:porisrɔm
# Started 267
# Started 267 ফরে
# Ended 267:ফরে
# 267:pʰɔre
# Started 268
# Started 268 ফরার
# Ended 268:ফরার
# 268:pʰɔrar
# Started 269
# Started 269 শিটের
# Ended 269:শিটের
# 269:ʃiter
# Started 270
# Started 270 স্যারে
# Ended 270:স্যারে
# 270:sære
# Started 271
# Started 271 যে
# Ended 271:যে
# 271:ɟe
# Started 272
# Started 272 প্রাইভেট
# Ended 272:প্রাইভেট
# 272:pra͡i̯bʱet
# Started 273
# Started 273 নিয়ম
# Ended 619:ফালাইবু
# 619:pʰala͡i̯bu
# Started 620
# Started 620 ইয়ে
# Ended 273:নিয়ম
# 273:niʲom
# Started 274
# Started 274 কুয়েশ্চন
# Ended 620:ইয়ে
# 620:iʲe
# Started 621
# Started 621 ইতেরে
# Ended 621:ইতেরে
# 621:it̪ere
# Started 622
# Started 622 কারণ
# Ended 622:কারণ
# 622:karon
# Started 623
# Started 623 ওয়ার্ড
# Ended 623:ওয়ার্ড
# 623:oʷard
# Started 624
# Started 624 ফুরো
# Ended 624:ফুরো
# 624:pʰuro
# Started 625
# Started 625 রাত
# Ended 625:রাত
# 625:rat̪
# Started 626
# Started 626 বেলা
# Ended 626:বেলা
# 626:bela
# Started 627
# Started 627 উইদ্দো
# Ended 627:উইদ্দো
# 627:u͡i̯d̪d̪o
# Started 628
# Started 628 দুনোউয়ার
# Ended 628:দুনোউয়ার
# 628:d̪uno͡u̯ʲar
# Started 629
# Started 629 ফইরজে
# Ended 1004:দুইজ্জা
# 1004:d̪u͡i̯ɟɟa
# Started 1005
# Started 1005 ভাত
# Ended 1005:ভাত
# 1005:bʱat̪
# Started 1006
# Started 1006 খাইতে
# Ended 1006:খাইতে
# 1006:kʰa͡i̯t̪e
# Started 1007
# Started 1007 যাইতাম
# Ended 1007:যাইতাম
# 1007:ɟa͡i̯t̪am
# Started 1008
# Started 1008 যাইয়েনে
# Ended 111:আইজু
# 111:a͡i̯ɟu
# Started 112
# Started 112 জিনিসপত্র
# Ended 112:জিনিসপত্র
# 112:ɟiniʃpɔt̪ro
# Started 113
# Started 113 জীবন
# Ended 113:জীবন
# 113:ɟibɔn
# Started 114
# Started 114 সাইরদি
# Ended 114:সাইরদি
# 114:sa͡i̯rod̪i
# Started 115
# Started 115 আঁই
# Ended 115:আঁই
# 115:ãi
# Started 116
# Started 116 দংশ
# Ended 116:দংশ
# 116:d̪ɔŋʃo
# Started 117
# Started 117 বউত
# Ended 117:বউত
# 117:bɔ͡u̯t̪o
# Started 118
# Started 118 অয়
# Ended 118:অয়
# 118:ɔʲ
# Started 119
# Started 119 ইভেন
# Ended 119:ইভেন
# 119:ibʱen
# Started 120
# Started 120 ক্লাসত
# Ended 120:ক্লাসত
# 120:klaʃɔt̪o
# Started 121
# Started 121 ফরাটরা
# Ended 121:ফরাটরা
# 121:pʰɔratra
# Started 122
# Started 122 গেলে
# Ended 122:গেলে
# 122:gele
# Started 123
# Started 123 গইরজম
# Ended 123:গইরজম
# 123:go͡i̯roɟɔm
# Started 124
# Started 124 থাহে
# Ended 124:থাহে
# 124:t̪ʰahe
# Started 125
# Started 125 যাই
# Ended 125:যাই
# 125:ɟa͡i̯
# Started 126
# Started 126 এইদিন
# Ended 126:এইদিন
# 126:e͡i̯d̪in
# Started 127
# Started 127 কেয়ামত
# Ended 127:কেয়ামত
# 127:keʲamɔt̪
# Started 128
# Started 128 ফাইউম
# Ended 128:ফাইউম
# 128:pʰa͡i̯um
# Started 129
# Started 129 আল্লাহ
# Ended 129:আল্লাহ
# 129:allah
# Started 130
# Started 130 ক্লাসের
# Ended 130:ক্লাসের
# 130:klaser
# Started 131
# Started 131 অন্য
# Ended 131:অন্য
# 131:ɔnno
# Started 132
# Started 132 মানুষ
# Ended 132:মানুষ
# 132:manuʃ
# Started 133
# Started 133 যারা
# Ended 133:যারা
# 133:ɟara
# Started 134
# Started 134 যায়
# Ended 134:যায়
# 134:ɟaʲ
# Started 135
# Started 135 ইয়্যিনের
# Ended 135:ইয়্যিনের
# 135:ikiner
# Started 136
# Started 136 ফুছর
# Ended 136:ফুছর
# 136:pʰucʰɔr
# Started 137
# Started 137 গরিয়েনে
# Ended 137:গরিয়েনে
# 137:goriʲene
# Started 138
# Started 138 লওন
# Ended 138:লওন
# 138:lɔ͡o̯n
# Started 139
# Started 139 ফরিবু
# Ended 139:ফরিবু
# 139:pʰoribu
# Started 140
# Started 140 যাইতু
# Ended 140:যাইতু
# 140:ɟa͡i̯t̪u
# Started 141
# Started 141 গ্যারান্টি
# Ended 141:গ্যারান্টি
# 141:gæranti
# Started 142
# Started 142 দি
# Ended 142:দি
# 142:d̪i
# Started 143
# Started 143 খইত
# Ended 143:খইত
# 143:kʰo͡i̯t̪o
# Started 144
# Started 144 ফাইরজুম
# Ended 1408:কক্সবাজাররে
# 1408:kɔksbaɟarre
# Started 1409
# Started 1409 সবসময়ই
# Ended 1409:সবসময়ই
# 1409:ʃɔbʃɔmɔʲi
# Started 1410
# Started 1410 কাছের
# Ended 1410:কাছের
# 1410:kacʰer
# Started 1411
# Started 1411 হিসেবেই
# Ended 1411:হিসেবেই
# 1411:hiʃebe͡i̯
# Started 1412
# Started 1412 থাকিবো
# Ended 1608:খইয়্যু
# 1608:kʰo͡i̯ʲd̪ʱu
# Started 1609
# Started 1609 খারণ
# Ended 428:পাঁচ
# 428:pãc
# Started 429
# Started 429 বছর
# Ended 429:বছর
# 429:bɔcʰor
# Started 430
# Started 430 ধরি
# Ended 430:ধরি
# 430:d̪ʱori
# Started 431
# Started 431 হঅর
# Ended 831:গইজঝি
# 831:gɔ͡i̯ɟɟʱi
# Started 832
# Started 832 হত
# Ended 832:হত
# 832:hɔt̪o
# Started 833
# Started 833 ধরনর
# Ended 833:ধরনর
# 833:d̪ʱɔronɔr
# Started 834
# Started 834 স্কুল
# Ended 834:স্কুল
# 834:skul
# Started 835
# Started 835 আনত
# Ended 835:আনত
# 835:anot̪o
# Started 836
# Started 836 পড়াশোনা
# Ended 836:পড়াশোনা
# 836:pɔɽaʃona
# Started 837
# Started 837 গইরতাম
# Ended 629:ফইরজে
# 629:pʰo͡i̯rɟe
# Started 630
# Started 630 অর্ণবেরে
# Ended 630:অর্ণবেরে
# 630:ɔrnobere
# Started 631
# Started 631 অর্ণব
# Ended 631:অর্ণব
# 631:ɔrnob
# Started 632
# Started 632 কিরজি
# Ended 632:কিরজি
# 632:kiroɟi
# Started 633
# Started 633 বয়াবাইর
# Ended 633:বয়াবাইর
# 633:bɔʲaba͡i̯r
# Started 634
# Started 634 টাইমে
# Ended 634:টাইমে
# 634:ta͡i̯me
# Started 635
# Started 635 চাইলে
# Ended 635:চাইলে
# 635:ca͡i̯le
# Started 636
# Started 636 ইত
# Ended 636:ইত
# 636:it̪o
# Started 637
# Started 637 হুনের
# Ended 1209:রাজস্বও
# 1209:raɟoʃʃo
# Started 1210
# Started 1210 ট্যুরিস্ট
# Ended 1210:ট্যুরিস্ট
# 1210:turist
# Started 1211
# Started 1211 পর্যটন
# Ended 1211:পর্যটন
# 1211:porɟoton
# Started 1212
# Started 1212 খাত
# Ended 1212:খাত
# 1212:kʰat̪
# Started 1213
# Started 1213 উল্লেখযোগ্য
# Ended 1213:উল্লেখযোগ্য
# 1213:ullekʰɟoggo
# Started 1214
# Started 1214 শৈবাল
# Ended 1214:শৈবাল
# 1214:ʃo͡i̯bal
# Started 1215
# Started 1215 বিচে
# Ended 1215:বিচে
# 1215:bice
# Started 1216
# Started 1216 যাইতে
# Ended 1216:যাইতে
# 1216:ɟa͡i̯t̪e
# Started 1217
# Started 1217 ঝাউগাছর
# Ended 1807:জিরায়-টিরায়
# 1807:ɟiraʲ-tiraʲ
# Started 1808
# Started 1808 লইতু
# Ended 431:হঅর
# 431:hɔ͡ɔ̯r
# Started 432
# Started 432 আরা
# Ended 432:আরা
# 432:ara
# Started 433
# Started 433 প্রেডিক্ট
# Ended 433:প্রেডিক্ট
# 433:predikt
# Started 434
# Started 434 ফেলাইয়িদে
# Ended 1609:খারণ
# 1609:kʰaron
# Started 1610
# Started 1610 ফাঁচ
# Ended 1610:ফাঁচ
# 1610:pʰãc
# Started 1611
# Started 1611 প্রায়
# Ended 1611:প্রায়
# 1611:praʲ
# Started 1612
# Started 1612 আনন
# Ended 274:কুয়েশ্চন
# 274:kuʲeʃcon
# Started 275
# Started 275 আইবু
# Ended 1008:যাইয়েনে
# 1008:ɟa͡i̯ʲene
# Started 1009
# Started 1009 হাজির
# Ended 1009:হাজির
# 1009:haɟir
# Started 1010
# Started 1010 অইতাম
# Ended 144:ফাইরজুম
# 144:pʰa͡i̯rɟum
# Started 145
# Started 145 গেইলেও
# Ended 145:গেইলেও
# 145:ge͡i̯le͡o̯
# Started 146
# Started 146 খাতাত
# Ended 146:খাতাত
# 146:kʰat̪at̪
# Started 147
# Started 147 থাইবু
# Ended 1412:থাকিবো
# 1412:t̪ʰakibo
# Started 1413
# Started 1413 অনরা
# Ended 637:হুনের
# 637:huner
# Started 638
# Started 638 বওয়াই
# Ended 638:বওয়াই
# 638:boʷa͡i̯
# Started 639
# Started 639 গইরজে
# Ended 639:গইরজে
# 639:go͡i̯rɟe
# Started 640
# Started 640 লাইবু
# Ended 640:লাইবু
# 640:la͡i̯bu
# Started 641
# Started 641 ফনেরো
# Ended 641:ফনেরো
# 641:pʰɔnero
# Started 642
# Started 642 পেইজের
# Ended 642:পেইজের
# 642:pe͡i̯ɟer
# Started 643
# Started 643 নি
# Ended 643:নি
# 643:ni
# Started 644
# Started 644 ঝামেলা
# Ended 644:ঝামেলা
# 644:ɟʱamela
# Started 645
# Started 645 ম্যামে
# Ended 645:ম্যামে
# 645:mæme
# Started 646
# Started 646 বারবার
# Ended 646:বারবার
# 646:barbar
# Started 647
# Started 647 পেইজ
# Ended 647:পেইজ
# 647:pe͡i̯ɟ
# Started 648
# Started 648 থওন
# Ended 648:থওন
# 648:æ͡o̯n
# Started 649
# Started 649 মিলাইয়েনে
# Ended 649:মিলাইয়েনে
# 649:mila͡i̯ʲene
# Started 650
# Started 650 থাও
# Ended 650:থাও
# 650:t̪ʰa͡o̯
# Started 651
# Started 651 এক্সেপ্ট
# Ended 651:এক্সেপ্ট
# 651:eksept
# Started 652
# Started 652 স্লাইড
# Ended 652:স্লাইড
# 652:sla͡i̯d
# Started 653
# Started 653 বাকি
# Ended 653:বাকি
# 653:baki
# Started 654
# Started 654 লাস্টের
# Ended 654:লাস্টের
# 654:laster
# Started 655
# Started 655 এন্ডিং
# Ended 655:এন্ডিং
# 655:ændiŋ
# Started 656
# Started 656 ফার্স্টের
# Ended 656:ফার্স্টের
# 656:pʰarster
# Started 657
# Started 657 স্টার্টিং
# Ended 657:স্টার্টিং
# 657:startiŋ
# Started 658
# Started 658 লইয়েনে
# Ended 837:গইরতাম
# 837:girot̪am
# Started 838
# Started 838 পড়াশোনার
# Ended 838:পড়াশোনার
# 838:pɔɽaʃonar
# Started 839
# Started 839 ফাঁকে
# Ended 839:ফাঁকে
# 839:pʰãke
# Started 840
# Started 840 টেবিলত
# Ended 840:টেবিলত
# 840:tebilɔt̪o
# Started 841
# Started 841 কলম
# Ended 841:কলম
# 841:kɔlom
# Started 842
# Started 842 ফাইট
# Ended 842:ফাইট
# 842:pʰa͡i̯t
# Started 843
# Started 843 গরিতাম
# Ended 1612:আনন
# 1612:anon
# Started 1613
# Started 1613 উচিৎ
# Ended 1613:উচিৎ
# 1613:ucit̪
# Started 1614
# Started 1614 তারফরেও
# Ended 1614:তারফরেও
# 1614:t̪arpʰɔre͡o̯
# Started 1615
# Started 1615 ওইসময়
# Ended 1615:ওইসময়
# 1615:o͡i̯ʃɔmɔʲ
# Started 1616
# Started 1616 ব্যাচমেট
# Ended 1808:লইতু
# 1808:lo͡i̯t̪u
# Started 1809
# Started 1809 এ্যান-ট্যান
# Ended 275:আইবু
# 275:a͡i̯bu
# Started 276
# Started 276 অ্যাঁ
# Ended 276:অ্যাঁ
# 276:æ̃
# Started 277
# Started 277 ধরো
# Ended 277:ধরো
# 277:d̪ʱɔro
# Started 278
# Started 278 তোঁয়ারে
# Ended 278:তোঁয়ারে
# 278:t̪õʷare
# Started 279
# Started 279 দিয়্যে
# Ended 279:দিয়্যে
# 279:d̪ikt̪e
# Started 280
# Started 280 প্রশ্ন
# Ended 280:প্রশ্ন
# 280:prosno
# Started 281
# Started 281 বারো
# Ended 281:বারো
# 281:baro
# Started 282
# Started 282 এডের
# Ended 282:এডের
# 282:eder
# Started 283
# Started 283 ফাচচো
# Ended 283:ফাচচো
# 283:pʰacco
# Started 284
# Started 284 বা
# Ended 284:বা
# 284:ba
# Started 285
# Started 285 ছউয়া
# Ended 285:ছউয়া
# 285:cʰɔ͡u̯ʲa
# Started 286
# Started 286 যেইগিন
# Ended 286:যেইগিন
# 286:ɟe͡i̯gin
# Started 287
# Started 287 আয়
# Ended 287:আয়
# 287:aʲ
# Started 288
# Started 288 আগেদি
# Ended 288:আগেদি
# 288:aged̪i
# Started 289
# Started 289 খতিকগিন
# Ended 289:খতিকগিন
# 289:kʰot̪ikgin
# Started 290
# Started 290 আবার
# Ended 290:আবার
# 290:abar
# Started 291
# Started 291 ইয়্যেনের
# Ended 291:ইয়্যেনের
# 291:iʲd̪ʱener
# Started 292
# Started 292 ই
# Ended 292:ই
# 292:i
# Started 293
# Started 293 ফাই
# Ended 293:ফাই
# 293:pʰa͡i̯
# Started 294
# Started 294 আঁর
# Ended 294:আঁর
# 294:ãr
# Started 295
# Started 295 নিজের
# Ended 295:নিজের
# 295:niɟer
# Started 296
# Started 296 যাইয়ানে
# Ended 296:যাইয়ানে
# 296:ɟa͡i̯ʲane
# Started 297
# Started 297 অথবা
# Ended 297:অথবা
# 297:ɔt̪ʰoba
# Started 298
# Started 298 স্যারেরতুন
# Ended 298:স্যারেরতুন
# 298:særert̪un
# Started 299
# Started 299 চোইদ্দবার
# Ended 299:চোইদ্দবার
# 299:co͡i̯d̪d̪obar
# Started 300
# Started 300 তঁয়
# Ended 300:তঁয়
# 300:t̪ɔ̃ʲ
# Started 301
# Started 301 দিয়্যুনা
# Ended 1010:অইতাম
# 1010:ɔ͡i̯t̪am
# Started 1011
# Started 1011 দফা
# Ended 1011:দফা
# 1011:d̪ɔpʰa
# Started 1012
# Started 1012 আছর
# Ended 1012:আছর
# 1012:acʰor
# Started 1013
# Started 1013 ওক্তত
# Ended 1217:ঝাউগাছর
# 1217:ɟʱaŋgacʰor
# Started 1218
# Started 1218 মাঝখান
# Ended 1218:মাঝখান
# 1218:maɟʱkʰan
# Started 1219
# Started 1219 সময়
# Ended 1219:সময়
# 1219:ʃɔmɔʲ
# Started 1220
# Started 1220 পাইলে
# Ended 1220:পাইলে
# 1220:pa͡i̯le
# Started 1221
# Started 1221 ইক্কে
# Ended 147:থাইবু
# 147:t̪ʰa͡i̯bu
# Started 148
# Started 148 ইতারে
# Ended 148:ইতারে
# 148:it̪are
# Started 149
# Started 149 ফুসার
# Ended 149:ফুসার
# 149:pʰuʃar
# Started 150
# Started 150 তুসার
# Ended 150:তুসার
# 150:t̪uʃar
# Started 151
# Started 151 নঅগরো
# Ended 151:নঅগরো
# 151:nɔ͡ɔ̯gɔro
# Started 152
# Started 152 এগিন
# Ended 1413:অনরা
# 1413:ɔnɔra
# Started 1414
# Started 1414 কক্সবাজারে
# Ended 1414:কক্সবাজারে
# 1414:kɔksbaɟare
# Started 1415
# Started 1415 আইবেন
# Ended 434:ফেলাইয়িদে
# 434:pʰela͡i̯ʲid̪e
# Started 435
# Started 435 বইর
# Ended 435:বইর
# 435:bo͡i̯r
# Started 436
# Started 436 যাইলইও
# Ended 436:যাইলইও
# 436:ɟa͡i̯li͡o̯
# Started 437
# Started 437 অয়তো
# Ended 437:অয়তো
# 437:ɔʲt̪o
# Started 438
# Started 438 জিন্দেগিত
# Ended 438:জিন্দেগিত
# 438:ɟind̪egit̪o
# Started 439
# Started 439 ন-দেইকখম
# Ended 658:লইয়েনে
# 658:lo͡i̯ʲene
# Started 659
# Started 659 বন্ধু
# Ended 659:বন্ধু
# 659:bond̪ʱu
# Started 660
# Started 660 আরেক
# Ended 660:আরেক
# 660:arek
# Started 661
# Started 661 শয়তান
# Ended 661:শয়তান
# 661:ʃɔʲt̪an
# Started 662
# Started 662 চুল
# Ended 662:চুল
# 662:cul
# Started 663
# Started 663 বেয়াকগিন
# Ended 663:বেয়াকগিন
# 663:beʲakgin
# Started 664
# Started 664 আঁরি
# Ended 664:আঁরি
# 664:ãri
# Started 665
# Started 665 ফালাই
# Ended 665:ফালাই
# 665:pʰala͡i̯
# Started 666
# Started 666 বন্ধুর
# Ended 666:বন্ধুর
# 666:bond̪ʱur
# Started 667
# Started 667 অর্ণবের
# Ended 667:অর্ণবের
# 667:ɔrnober
# Started 668
# Started 668 ফালাইতাম
# Ended 668:ফালাইতাম
# 668:pʰala͡i̯t̪am
# Started 669
# Started 669 আঁরতুন
# Ended 669:আঁরতুন
# 669:ãrt̪un
# Started 670
# Started 670 দিয়্যস
# Ended 670:দিয়্যস
# 670:d̪ikt̪oʃ
# Started 671
# Started 671 কা
# Ended 671:কা
# 671:ka
# Started 672
# Started 672 ইতিরতে
# Ended 672:ইতিরতে
# 672:it̪irɔt̪e
# Started 673
# Started 673 আপসারাপ
# Ended 673:আপসারাপ
# 673:apʃarap
# Started 674
# Started 674 গুতাইন্না
# Ended 674:গুতাইন্না
# 674:gut̪a͡i̯nna
# Started 675
# Started 675 রোগ
# Ended 675:রোগ
# 675:rog
# Started 676
# Started 676 উইঠটি
# Ended 843:গরিতাম
# 843:gorit̪am
# Started 844
# Started 844 শারীরিক
# Ended 844:শারীরিক
# 844:ʃaririk
# Started 845
# Started 845 শিক্ষা
# Ended 845:শিক্ষা
# 845:ʃikkʰa
# Started 846
# Started 846 মাইঝে
# Ended 846:মাইঝে
# 846:ma͡i̯ɟʱe
# Started 847
# Started 847 মাঠর
# Ended 847:মাঠর
# 847:matʰor
# Started 848
# Started 848 বেককুন
# Ended 848:বেককুন
# 848:bekkun
# Started 849
# Started 849 ফুয়াজজাঅল
# Ended 152:এগিন
# 152:egin
# Started 153
# Started 153 এগিনোর
# Ended 153:এগিনোর
# 153:eginor
# Started 154
# Started 154 হাতাত
# Ended 154:হাতাত
# 154:hat̪at̪
# Started 155
# Started 155 নামবার
# Ended 155:নামবার
# 155:nambar
# Started 156
# Started 156 নাই
# Ended 156:নাই
# 156:na͡i̯
# Started 157
# Started 157 ইনোর
# Ended 157:ইনোর
# 157:inor
# Started 158
# Started 158 প্রেজেনটেশনত
# Ended 158:প্রেজেনটেশনত
# 158:preɟenteʃonɔt̪
# Started 159
# Started 159 একসট্রা
# Ended 159:একসট্রা
# 159:ækʃotra
# Started 160
# Started 160 কারিকুলামত
# Ended 160:কারিকুলামত
# 160:karikulamɔt̪
# Started 161
# Started 161 আরার
# Ended 161:আরার
# 161:arar
# Started 162
# Started 162 ভারসিটির
# Ended 162:ভারসিটির
# 162:bʱarsitir
# Started 163
# Started 163 বেক
# Ended 163:বেক
# 163:bek
# Started 164
# Started 164 কিসুত
# Ended 164:কিসুত
# 164:kiʃut̪
# Started 165
# Started 165 কমপিটিশন
# Ended 1013:ওক্তত
# 1013:okt̪ot̪o
# Started 1014
# Started 1014 ডেইলি
# Ended 1221:ইক্কে
# 1221:ikke
# Started 1222
# Started 1222 ফুটবল
# Ended 1014:ডেইলি
# 1014:de͡i̯li
# Started 1015
# Started 1015 খেলিতে
# Ended 1015:খেলিতে
# 1015:kʰelit̪e
# Started 1016
# Started 1016 নেশা
# Ended 1016:নেশা
# 1016:neʃa
# Started 1017
# Started 1017 সৃষ্টি
# Ended 1017:সৃষ্টি
# 1017:sriʃti
# Started 1018
# Started 1018 গেইয়্যিল
# Ended 1415:আইবেন
# 1415:a͡i̯ben
# Started 1416
# Started 1416 ঘুরি
# Ended 1416:ঘুরি
# 1416:gʱuri
# Started 1417
# Started 1417 যাইবেন
# Ended 1417:যাইবেন
# 1417:ɟa͡i̯ben
# Started 1418
# Started 1418 মানুষজনর
# Ended 1616:ব্যাচমেট
# 1616:bæcmet
# Started 1617
# Started 1617 ইন্টার
# Ended 1617:ইন্টার
# 1617:intar
# Started 1618
# Started 1618 ইয়ার
# Ended 1618:ইয়ার
# 1618:iʲar
# Started 1619
# Started 1619 খোন
# Ended 301:দিয়্যুনা
# 301:d̪ikuna
# Started 302
# Started 302 ইয়াত
# Ended 302:ইয়াত
# 302:iʲat̪
# Started 303
# Started 303 আছেনা
# Ended 303:আছেনা
# 303:acʰena
# Started 304
# Started 304 এর
# Ended 304:এর
# 304:er
# Started 305
# Started 305 আগে
# Ended 305:আগে
# 305:age
# Started 306
# Started 306 ফাইতাম
# Ended 306:ফাইতাম
# 306:pʰa͡i̯t̪am
# Started 307
# Started 307 বড়
# Ended 307:বড়
# 307:bɔɽo
# Started 308
# Started 308 সাইর
# Ended 308:সাইর
# 308:sa͡i̯r
# Started 309
# Started 309 কোর্স
# Ended 309:কোর্স
# 309:kors
# Started 310
# Started 310 তিননোত
# Ended 676:উইঠটি
# 676:u͡i̯tʰti
# Started 677
# Started 677 হইছে
# Ended 677:হইছে
# 677:ho͡i̯cʰe
# Started 678
# Started 678 হইছের
# Ended 678:হইছের
# 678:ho͡i̯cʰer
# Started 679
# Started 679 গুষ্টি
# Ended 679:গুষ্টি
# 679:guʃti
# Started 680
# Started 680 কিলাই
# Ended 1809:এ্যান-ট্যান
# 1809:t̪ænɔ-tan
# Started 1810
# Started 1810 ধরা-টরা
# Ended 1619:খোন
# 1619:kʰon
# Started 1620
# Started 1620 উন্নিশ
# Ended 1620:উন্নিশ
# 1620:unniʃ
# Started 1621
# Started 1621 সালর
# Ended 1621:সালর
# 1621:salor
# Started 1622
# Started 1622 কলেজর
# Ended 1622:কলেজর
# 1622:kɔleɟɔr
# Started 1623
# Started 1623 আছিলো
# Ended 1623:আছিলো
# 1623:acʰilo
# Started 1624
# Started 1624 বিশেষ
# Ended 1624:বিশেষ
# 1624:biʃeʃ
# Started 1625
# Started 1625 ফোয়ার
# Ended 439:ন-দেইকখম
# 439:n-d̪e͡i̯kkʰɔm
# Started 440
# Started 440 এইনলা
# Ended 440:এইনলা
# 440:e͡i̯nla
# Started 441
# Started 441 লার
# Ended 441:লার
# 441:lar
# Started 442
# Started 442 ভার্সিটিতও
# Ended 442:ভার্সিটিতও
# 442:bʱarsitit̪o
# Started 443
# Started 443 একই
# Ended 443:একই
# 443:æko͡i̯
# Started 444
# Started 444 কাহিনী
# Ended 444:কাহিনী
# 444:kahini
# Started 445
# Started 445 হুইনতাম
# Ended 445:হুইনতাম
# 445:hu͡i̯not̪am
# Started 446
# Started 446 শুরু
# Ended 446:শুরু
# 446:ʃuru
# Started 447
# Started 447 আইবার
# Ended 447:আইবার
# 447:a͡i̯bar
# Started 448
# Started 448 যাইবুগই
# Ended 448:যাইবুগই
# 448:ɟa͡i̯bugi
# Started 449
# Started 449 করোনা
# Ended 449:করোনা
# 449:kɔrona
# Started 450
# Started 450 মরোনা
# Ended 450:মরোনা
# 450:mɔrona
# Started 451
# Started 451 আই
# Ended 451:আই
# 451:a͡i̯
# Started 452
# Started 452 খডের
# Ended 452:খডের
# 452:kʰɔder
# Started 453
# Started 453 ওমা
# Ended 453:ওমা
# 453:oma
# Started 454
# Started 454 খুলিবার
# Ended 454:খুলিবার
# 454:kʰulibar
# Started 455
# Started 455 খতাবার্তা
# Ended 455:খতাবার্তা
# 455:kʰɔt̪abart̪a
# Started 456
# Started 456 হয়
# Ended 456:হয়
# 456:hɔʲ
# Started 457
# Started 457 বেয়াকগুনের
# Ended 457:বেয়াকগুনের
# 457:beʲakguner
# Started 458
# Started 458 মার্সিটি
# Ended 458:মার্সিটি
# 458:marsiti
# Started 459
# Started 459 সরাই
# Ended 459:সরাই
# 459:ʃɔra͡i̯
# Started 460
# Started 460 খইরদে
# Ended 460:খইরদে
# 460:kʰo͡i̯͡i̯d̪e
# Started 461
# Started 461 এইবার
# Ended 461:এইবার
# 461:e͡i̯bar
# Started 462
# Started 462 তোরা
# Ended 462:তোরা
# 462:t̪ora
# Started 463
# Started 463 আশুলিয়া
# Ended 463:আশুলিয়া
# 463:aʃuliʲa
# Started 464
# Started 464 অইলো
# Ended 464:অইলো
# 464:ɔ͡i̯lo
# Started 465
# Started 465 লয়
# Ended 465:লয়
# 465:lɔʲ
# Started 466
# Started 466 মজা
# Ended 466:মজা
# 466:mɔɟa
# Started 467
# Started 467 লইলো
# Ended 467:লইলো
# 467:lo͡i̯lo
# Started 468
# Started 468 হুম
# Ended 468:হুম
# 468:hum
# Started 469
# Started 469 তাও
# Ended 469:তাও
# 469:t̪a͡o̯
# Started 470
# Started 470 কিরে
# Ended 470:কিরে
# 470:kire
# Started 471
# Started 471 মাবুদই
# Ended 471:মাবুদই
# 471:mabud̪i
# Started 472
# Started 472 তোঁয়ারারে
# Ended 1222:ফুটবল
# 1222:pʰutbɔl
# Started 1223
# Started 1223 খেলিবার
# Ended 165:কমপিটিশন
# 165:kompitiʃon
# Started 166
# Started 166 এনে
# Ended 166:এনে
# 166:ene
# Started 167
# Started 167 এই
# Ended 167:এই
# 167:e͡i̯
# Started 168
# Started 168 জায়গাতো
# Ended 168:জায়গাতো
# 168:ɟaʲgat̪o
# Started 169
# Started 169 ইয়ান
# Ended 169:ইয়ান
# 169:iʲan
# Started 170
# Started 170 দাম
# Ended 170:দাম
# 170:d̪am
# Started 171
# Started 171 জাগাত
# Ended 171:জাগাত
# 171:ɟagat̪
# Started 172
# Started 172 ফারে
# Ended 172:ফারে
# 172:pʰare
# Started 173
# Started 173 বুঝের
# Ended 849:ফুয়াজজাঅল
# 849:pʰuʲaɟɟa͡ɔ̯l
# Started 850
# Started 850 বেককুনে
# Ended 850:বেককুনে
# 850:bekkune
# Started 851
# Started 851 মিলিয়নে
# Ended 851:মিলিয়নে
# 851:miliʲone
# Started 852
# Started 852 লুকোচুরি
# Ended 852:লুকোচুরি
# 852:lukocuri
# Started 853
# Started 853 খেলিতাম
# Ended 1018:গেইয়্যিল
# 1018:ge͡i̯kil
# Started 1019
# Started 1019 গই
# Ended 680:কিলাই
# 680:kila͡i̯
# Started 681
# Started 681 খইদি
# Ended 681:খইদি
# 681:kʰid̪i
# Started 682
# Started 682 ইতের
# Ended 682:ইতের
# 682:it̪er
# Started 683
# Started 683 গরিবার
# Ended 683:গরিবার
# 683:goribar
# Started 684
# Started 684 আইয়ানে
# Ended 684:আইয়ানে
# 684:a͡i̯ʲane
# Started 685
# Started 685 খর
# Ended 310:তিননোত
# 310:t̪innot̪o
# Started 311
# Started 311 হাইয়েস্ট
# Ended 311:হাইয়েস্ট
# 311:ha͡i̯ʲest
# Started 312
# Started 312 মাশাল্লাহ
# Ended 312:মাশাল্লাহ
# 312:maʃallah
# Started 313
# Started 313 নিজে
# Ended 313:নিজে
# 313:niɟe
# Started 314
# Started 314 খুঁজি
# Ended 314:খুঁজি
# 314:kʰũɟi
# Started 315
# Started 315 জিনিস
# Ended 315:জিনিস
# 315:ɟiniʃ
# Started 316
# Started 316 লিখি
# Ended 316:লিখি
# 316:likʰi
# Started 317
# Started 317 কারন
# Ended 317:কারন
# 317:karon
# Started 318
# Started 318 ফরেদি
# Ended 318:ফরেদি
# 318:pʰɔred̪i
# Started 319
# Started 319 ফাইয়্যুম
# Ended 319:ফাইয়্যুম
# 319:pʰa͡i̯ʲd̪ʱum
# Started 320
# Started 320 কেওর
# Ended 320:কেওর
# 320:ke͡o̯r
# Started 321
# Started 321 মাথাত
# Ended 321:মাথাত
# 321:mat̪ʰat̪
# Started 322
# Started 322 সেট
# Ended 322:সেট
# 322:ʃet
# Started 323
# Started 323 বাংকও
# Ended 323:বাংকও
# 323:baŋko
# Started 324
# Started 324 দিত
# Ended 324:দিত
# 324:d̪it̪o
# Started 325
# Started 325 ফারির
# Ended 1418:মানুষজনর
# 1418:manuʃɟɔnor
# Started 1419
# Started 1419 মিশিবান
# Ended 1625:ফোয়ার
# 1625:pʰoʷar
# Started 1626
# Started 1626 মইদ্দে
# Ended 1626:মইদ্দে
# 1626:mo͡i̯d̪d̪e
# Started 1627
# Started 1627 গ্রামর
# Ended 1810:ধরা-টরা
# 1810:d̪ʱɔra-tra
# Started 1811
# Started 1811 খাইয়্যে
# Ended 1019:গই
# 1019:go͡i̯
# Started 1020
# Started 1020 এনও
# Ended 685:খর
# 685:kʰɔr
# Started 686
# Started 686 উইতারে
# Ended 686:উইতারে
# 686:u͡i̯t̪are
# Started 687
# Started 687 গ্রুপ
# Ended 687:গ্রুপ
# 687:grup
# Started 688
# Started 688 কলে
# Ended 688:কলে
# 688:kɔle
# Started 689
# Started 689 ডাকি
# Ended 689:ডাকি
# 689:daki
# Started 690
# Started 690 উইতে
# Ended 690:উইতে
# 690:u͡i̯t̪e
# Started 691
# Started 691 জামাই
# Ended 691:জামাই
# 691:ɟama͡i̯
# Started 692
# Started 692 বউ
# Ended 692:বউ
# 692:bɔ͡u̯
# Started 693
# Started 693 আইসসে
# Ended 693:আইসসে
# 693:a͡i̯sʃe
# Started 694
# Started 694 কল
# Ended 694:কল
# 694:kɔl
# Started 695
# Started 695 উইদ্দে
# Ended 695:উইদ্দে
# 695:u͡i̯d̪d̪e
# Started 696
# Started 696 ঝগড়া
# Ended 696:ঝগড়া
# 696:ɟʱɔgɽa
# Started 697
# Started 697 ফালাইবার
# Ended 697:ফালাইবার
# 697:pʰala͡i̯bar
# Started 698
# Started 698 খইস
# Ended 1223:খেলিবার
# 1223:kʰelibar
# Started 1224
# Started 1224 প্রত্যেকদিন
# Ended 1224:প্রত্যেকদিন
# 1224:prot̪t̪ekd̪in
# Started 1225
# Started 1225 শান্তি
# Ended 1225:শান্তি
# 1225:ʃant̪i
# Started 1226
# Started 1226 মর্নিং
# Ended 1226:মর্নিং
# 1226:mɔrniŋ
# Started 1227
# Started 1227 ওয়াক
# Ended 1227:ওয়াক
# 1227:oʷak
# Started 1228
# Started 1228 গরিতো
# Ended 173:বুঝের
# 173:buɟʱer
# Started 174
# Started 174 সাধারণ
# Ended 174:সাধারণ
# 174:ʃad̪ʱaron
# Started 175
# Started 175 এক্কান
# Ended 175:এক্কান
# 175:ækkan
# Started 176
# Started 176 তোঁয়ার
# Ended 176:তোঁয়ার
# 176:t̪õʲar
# Started 177
# Started 177 ইয়া
# Ended 177:ইয়া
# 177:iʲa
# Started 178
# Started 178 প্রজেক্টেরের
# Ended 178:প্রজেক্টেরের
# 178:proɟekterer
# Started 179
# Started 179 কম্পিউটার
# Ended 179:কম্পিউটার
# 179:kɔmpi͡u̯tar
# Started 180
# Started 180 গান
# Ended 180:গান
# 180:gan
# Started 181
# Started 181 অন
# Ended 181:অন
# 181:ɔn
# Started 182
# Started 182 গরিয়ানে
# Ended 182:গরিয়ানে
# 182:goriʲane
# Started 183
# Started 183 চাপে
# Ended 183:চাপে
# 183:cape
# Started 184
# Started 184 মাউস
# Ended 184:মাউস
# 184:ma͡u̯s
# Started 185
# Started 185 দিয়েনে
# Ended 185:দিয়েনে
# 185:d̪iʲene
# Started 186
# Started 186 দুনোউয়ান
# Ended 186:দুনোউয়ান
# 186:d̪uno͡u̯ʲan
# Started 187
# Started 187 ও
# Ended 187:ও
# 187:o
# Started 188
# Started 188 মানলাম
# Ended 188:মানলাম
# 188:manlam
# Started 189
# Started 189 মাইয়াফোয়া
# Ended 189:মাইয়াফোয়া
# 189:ma͡i̯ʲapʰoʷa
# Started 190
# Started 190 জানে
# Ended 190:জানে
# 190:ɟane
# Started 191
# Started 191 ইতি
# Ended 191:ইতি
# 191:it̪i
# Started 192
# Started 192 অক্কল
# Ended 192:অক্কল
# 192:ɔkkol
# Started 193
# Started 193 আঁইও
# Ended 193:আঁইও
# 193:ãi͡o̯
# Started 194
# Started 194 ফারি
# Ended 194:ফারি
# 194:pʰari
# Started 195
# Started 195 হিসেবে
# Ended 195:হিসেবে
# 195:hiʃebe
# Started 196
# Started 196 উইতি
# Ended 196:উইতি
# 196:u͡i̯t̪i
# Started 197
# Started 197 কেন
# Ended 197:কেন
# 197:keno
# Started 198
# Started 198 ফোয়া
# Ended 198:ফোয়া
# 198:pʰoʷa
# Started 199
# Started 199 অইয়্যেনে
# Ended 199:অইয়্যেনে
# 199:ɔ͡i̯kd̪ʱene
# Done
# Ended 1020:এনও
# 1020:eno
# Started 1021
# Started 1021 রোজার
# Ended 1021:রোজার
# 1021:roɟar
# Started 1022
# Started 1022 সমত
# Ended 698:খইস
# 698:kʰo͡i̯ʃ
# Started 699
# Started 699 পার্ট
# Ended 699:পার্ট
# 699:part
# Started 700
# Started 700 ফালাইয়্যুম
# Ended 325:ফারির
# 325:pʰarir
# Started 326
# Started 326 বাসা
# Ended 326:বাসা
# 326:baʃa
# Started 327
# Started 327 মাস্টারপুল
# Ended 327:মাস্টারপুল
# 327:mastarpul
# Started 328
# Started 328 বৌ
# Ended 328:বৌ
# 328:bo͡u̯
# Started 329
# Started 329 বাজার
# Ended 329:বাজার
# 329:baɟar
# Started 330
# Started 330 খুলশি
# Ended 330:খুলশি
# 330:kʰulʃi
# Started 331
# Started 331 থুন
# Ended 331:থুন
# 331:t̪ʰun
# Started 332
# Started 332 এন
# Ended 332:এন
# 332:en
# Started 333
# Started 333 জি
# Ended 333:জি
# 333:ɟi
# Started 334
# Started 334 করি
# Ended 334:করি
# 334:kori
# Started 335
# Started 335 গেইলি
# Ended 335:গেইলি
# 335:ge͡i̯li
# Started 336
# Started 336 লায়দে
# Ended 336:লায়দে
# 336:laʲd̪e
# Started 337
# Started 337 একশো
# Ended 337:একশো
# 337:ækʃo
# Started 338
# Started 338 আশি
# Ended 338:আশি
# 338:aʃi
# Started 339
# Started 339 দুইশো
# Ended 339:দুইশো
# 339:d̪u͡i̯ʃo
# Started 340
# Started 340 টেঁয়া
# Ended 340:টেঁয়া
# 340:tẽʲa
# Started 341
# Started 341 এতদূর
# Ended 341:এতদূর
# 341:æt̪od̪ur
# Started 342
# Started 342 জার্নি
# Ended 342:জার্নি
# 342:ɟarni
# Started 343
# Started 343 সকাল
# Ended 343:সকাল
# 343:ʃɔkal
# Started 344
# Started 344 নয়টা
# Ended 344:নয়টা
# 344:nɔʲta
# Started 345
# Started 345 বাজে
# Ended 345:বাজে
# 345:baɟe
# Started 346
# Started 346 নয়টার
# Ended 346:নয়টার
# 346:nɔʲtar
# Started 347
# Started 347 উডন
# Ended 347:উডন
# 347:udon
# Started 348
# Started 348 ছয়টা
# Ended 348:ছয়টা
# 348:cʰɔʲta
# Started 349
# Started 349 সাড়ে
# Ended 349:সাড়ে
# 349:ʃaɽe
# Started 350
# Started 350 সাতটা
# Ended 350:সাতটা
# 350:ʃat̪ta
# Started 351
# Started 351 বাসার
# Ended 351:বাসার
# 351:baʃar
# Started 352
# Started 352 বাইর
# Ended 352:বাইর
# 352:ba͡i̯r
# Started 353
# Started 353 অইতে
# Ended 353:অইতে
# 353:ɔ͡i̯t̪e
# Started 354
# Started 354 উডে
# Ended 354:উডে
# 354:ude
# Started 355
# Started 355 অরদে
# Ended 355:অরদে
# 355:ɔrd̪e
# Started 356
# Started 356 আটটা
# Ended 356:আটটা
# 356:atta
# Started 357
# Started 357 ঘন্টা
# Ended 357:ঘন্টা
# 357:gʱɔnta
# Started 358
# Started 358 এইগিনের
# Ended 358:এইগিনের
# 358:e͡i̯giner
# Started 359
# Started 359 গইরতে
# Ended 359:গইরতে
# 359:girt̪e
# Started 360
# Started 360 যারগুই
# Ended 472:তোঁয়ারারে
# 472:t̪õʷarare
# Started 473
# Started 473 কই
# Ended 473:কই
# 473:ko͡i̯
# Started 474
# Started 474 শুভকামনা
# Ended 474:শুভকামনা
# 474:ʃubʱkamona
# Started 475
# Started 475 বেশি
# Ended 475:বেশি
# 475:beʃi
# Started 476
# Started 476 হইবার
# Ended 476:হইবার
# 476:ho͡i̯bar
# Started 477
# Started 477 ছোড়ো
# Ended 477:ছোড়ো
# 477:cʰoɽo
# Started 478
# Started 478 একদম
# Ended 478:একদম
# 478:ækd̪ɔm
# Started 479
# Started 479 অইলদে
# Ended 479:অইলদে
# 479:ɔ͡i̯ld̪e
# Started 480
# Started 480 এককান
# Ended 480:এককান
# 480:ækkan
# Started 481
# Started 481 বিল্ডিং
# Ended 481:বিল্ডিং
# 481:bildiŋ
# Started 482
# Started 482 অর
# Ended 482:অর
# 482:ɔr
# Started 483
# Started 483 মতন
# Ended 483:মতন
# 483:mɔt̪on
# Started 484
# Started 484 নিচে
# Ended 484:নিচে
# 484:nice
# Started 485
# Started 485 যেনডিললা
# Ended 485:যেনডিললা
# 485:ɟendilɔla
# Started 486
# Started 486 হালকা
# Ended 486:হালকা
# 486:halka
# Started 487
# Started 487 স্পেইস
# Ended 487:স্পেইস
# 487:spe͡i̯s
# Started 488
# Started 488 তাহে
# Ended 488:তাহে
# 488:t̪ahe
# Started 489
# Started 489 এইললা
# Ended 489:এইললা
# 489:e͡i̯lla
# Started 490
# Started 490 এরে
# Ended 490:এরে
# 490:ere
# Started 491
# Started 491 গার্ডেন
# Ended 491:গার্ডেন
# 491:garden
# Started 492
# Started 492 হতা
# Ended 492:হতা
# 492:hɔt̪a
# Started 493
# Started 493 কমার্শিয়াল
# Ended 493:কমার্শিয়াল
# 493:kɔmarʃiʲal
# Started 494
# Started 494 সাইট
# Ended 494:সাইট
# 494:sa͡i̯t
# Started 495
# Started 495 সামনেও
# Ended 495:সামনেও
# 495:ʃamne͡o̯
# Started 496
# Started 496 তুয়ারার
# Ended 496:তুয়ারার
# 496:t̪uʲarar
# Started 497
# Started 497 উঠান
# Ended 497:উঠান
# 497:utʰan
# Started 498
# Started 498 মাঠ
# Ended 498:মাঠ
# 498:matʰ
# Started 499
# Started 499 এনডিললা
# Ended 499:এনডিললা
# 499:endilɔla
# Started 500
# Started 500 হালি
# Ended 500:হালি
# 500:hali
# Started 501
# Started 501 আছে।ইতারা
# Ended 501:আছে।ইতারা
# 501:acʰe।it̪ara
# Started 502
# Started 502 বানার
# Ended 502:বানার
# 502:banar
# Started 503
# Started 503 লাগেরদে
# Ended 503:লাগেরদে
# 503:lagerd̪e
# Started 504
# Started 504 তুই
# Ended 504:তুই
# 504:t̪u͡i̯
# Started 505
# Started 505 বানা
# Ended 505:বানা
# 505:bana
# Started 506
# Started 506 যিবা
# Ended 506:যিবা
# 506:ɟiba
# Started 507
# Started 507 মানসম্মত
# Ended 507:মানসম্মত
# 507:manoʃɔmmɔt̪ɔ
# Started 508
# Started 508 রাহিবি
# Ended 508:রাহিবি
# 508:rahibi
# Started 509
# Started 509 কমপক্ষে
# Ended 509:কমপক্ষে
# 509:kɔmpokkʰe
# Started 510
# Started 510 এক্কানা
# Ended 510:এক্কানা
# 510:ækkana
# Started 511
# Started 511 মান
# Ended 511:মান
# 511:man
# Started 512
# Started 512 থাহিবু
# Ended 853:খেলিতাম
# 853:kʰelit̪am
# Started 854
# Started 854 এড়ে
# Ended 854:এড়ে
# 854:eɽe
# Started 855
# Started 855 ভূতর
# Ended 855:ভূতর
# 855:bʱut̪ɔr
# Started 856
# Started 856 নামর
# Ended 856:নামর
# 856:namor
# Started 857
# Started 857 পরিত্যক্ত
# Ended 857:পরিত্যক্ত
# 857:porit̪ækt̪o
# Started 858
# Started 858 ইয়ানর
# Ended 858:ইয়ানর
# 858:iʲanor
# Started 859
# Started 859 সম্পর্কে
# Ended 859:সম্পর্কে
# 859:ʃɔmporke
# Started 860
# Started 860 আগ্রহ
# Ended 860:আগ্রহ
# 860:agroho
# Started 861
# Started 861 ভিতর
# Ended 861:ভিতর
# 861:bʱit̪or
# Started 862
# Started 862 তাইত
# Ended 862:তাইত
# 862:t̪a͡i̯t̪o
# Started 863
# Started 863 সবসময়
# Ended 863:সবসময়
# 863:ʃɔbʃɔmɔʲ
# Started 864
# Started 864 মাগরিবের
# Ended 864:মাগরিবের
# 864:magoriber
# Started 865
# Started 865 পরে
# Ended 865:পরে
# 865:pɔre
# Started 866
# Started 866 ইয়্যানর
# Ended 866:ইয়্যানর
# 866:iʲanɔr
# Started 867
# Started 867 ঘুরাঘুরি
# Ended 867:ঘুরাঘুরি
# 867:gʱuragʱuri
# Started 868
# Started 868 কিছি
# Ended 868:কিছি
# 868:kicʰi
# Started 869
# Started 869 দেহা-টেহা
# Ended 869:দেহা-টেহা
# 869:d̪eha-teha
# Started 870
# Started 870 যায়নে
# Ended 1627:গ্রামর
# 1627:gramɔr
# Started 1628
# Started 1628 ইতেও
# Ended 1419:মিশিবান
# 1419:miʃiban
# Started 1420
# Started 1420 গরিবান
# Ended 1811:খাইয়্যে
# 1811:kʰa͡i̯ʲt̪e
# Started 1812
# Started 1812 খাইয়্যেরে
# Ended 1022:সমত
# 1022:ʃɔmɔt̪
# Started 1023
# Started 1023 খইয়েনে
# Ended 1228:গরিতো
# 1228:gorit̪o
# Started 1229
# Started 1229 সওন
# Ended 1628:ইতেও
# 1628:it̪e͡o̯
# Started 1629
# Started 1629 লাইগদু
# Ended 870:যায়নে
# 870:ɟaʲne
# Started 871
# Started 871 দেহস
# Ended 871:দেহস
# 871:d̪ehoʃ
# Started 872
# Started 872 দেখি
# Ended 872:দেখি
# 872:d̪ekʰi
# Started 873
# Started 873 আসলে
# Ended 873:আসলে
# 873:aʃole
# Started 874
# Started 874 গুজবের
# Ended 874:গুজবের
# 874:guɟɔber
# Started 875
# Started 875 ডইল্লে
# Ended 875:ডইল্লে
# 875:dille
# Started 876
# Started 876 আইসছিল
# Ended 876:আইসছিল
# 876:a͡i̯scʰilo
# Started 877
# Started 877 এরি
# Ended 877:এরি
# 877:eri
# ...
# 4237:tomi
# Started 4238
# Started 4238 হঁরি
# Ended 5436:পৌছাই
# 5436:po͡u̯cʰa͡i̯
# Started 5437
# Started 5437 একা
# Ended 5437:একা
# 5437:æka
# Started 5438
# Started 5438 বইসতি
# Ended 4043:জামালখান
# 4043:ɟamalkʰan
# Started 4044
# Started 4044 কুটুমবাড়ি
# Ended 5645:উইন্দিত
# 5645:u͡i̯nd̪it̪o
# Started 5646
# Started 5646 বুঝছে
# Ended 5646:বুঝছে
# 5646:buɟʱcʰe
# Started 5647
# Started 5647 বুঝসনাই
# Ended 5845:ফাইলি
# 5845:pʰa͡i̯li
# Started 5846
# Started 5846 মজুরি
# Ended 5846:মজুরি
# 5846:moɟuri
# Started 5847
# Started 5847 ঝাপ
# Ended 5847:ঝাপ
# 5847:ɟʱap
# Started 5848
# Started 5848 দইরজাত
# Ended 4238:হঁরি
# 4238:hõri
# Started 4239
# Started 4239 উইট্টিতে
# Ended 5225:বেয়াককিছু
# 5225:beʲakkicʰu
# Started 5226
# Started 5226 টিকেট
# Ended 5226:টিকেট
# 5226:tiket
# Started 5227
# Started 5227 তিকেট
# Ended 4631:খানাদানা
# 4631:kʰanad̪ana
# Started 4632
# Started 4632 খাইয়ো
# Ended 5438:বইসতি
# 5438:bo͡i̯ʃt̪i
# Started 5439
# Started 5439 বসবে
# Ended 5439:বসবে
# 5439:boʃɔbe
# Started 5440
# Started 5440 খইলি
# Ended 5040:ফোয়ারতে
# 5040:pʰoʷart̪e
# Started 5041
# Started 5041 থাইলিও
# Ended 4434:রাইক্কি
# 4434:ra͡i̯kki
# Started 4435
# Started 4435 গরত
# Ended 4876:যাইবুগুই
# 4876:ɟa͡i̯bugu͡i̯
# Started 4877
# Started 4877 কেরাসিন
# Ended 4877:কেরাসিন
# 4877:keraʃin
# Started 4878
# Started 4878 তেলর
# Ended 4435:গরত
# 4435:gɔrot̪o
# Started 4436
# Started 4436 আম্মা
# Ended 4436:আম্মা
# 4436:amma
# Started 4437
# Started 4437 এক্কেনা
# Ended 5440:খইলি
# 5440:kʰili
# Started 5441
# Started 5441 খবি
# Ended 5647:বুঝসনাই
# 5647:buɟʱʃona͡i̯
# Started 5648
# Started 5648 গেছিলি
# Ended 5227:তিকেট
# 5227:t̪iket
# Started 5228
# Started 5228 ফুত
# Ended 5228:ফুত
# 5228:pʰut̪
# Started 5229
# Started 5229 গেয়লে
# Ended 5848:দইরজাত
# 5848:d̪o͡i̯rɟat̪
# Started 5849
# Started 5849 দিবুয়েনে
# Ended 4044:কুটুমবাড়ি
# 4044:kutumbaɽi
# Started 4045
# Started 4045 এটা
# Ended 4045:এটা
# 4045:eta
# Started 4046
# Started 4046 কোথায়
# Ended 4046:কোথায়
# 4046:kot̪ʰaʲ
# Started 4047
# Started 4047 চকবাজার
# Ended 4047:চকবাজার
# 4047:cɔkbaɟar
# Started 4048
# Started 4048 যান
# Ended 4048:যান
# 4048:ɟan
# Started 4049
# Started 4049 ডাইনে
# Ended 4049:ডাইনে
# 4049:da͡i̯ne
# Started 4050
# Started 4050 থেকে
# Ended 4050:থেকে
# 4050:t̪ʰeke
# Started 4051
# Started 4051 রিকশা
# Ended 4051:রিকশা
# 4051:rikʃa
# Started 4052
# Started 4052 খট্যা
# Ended 4632:খাইয়ো
# 4632:kʰa͡i̯ʲo
# Started 4633
# Started 4633 কিছুক্কণ
# Ended 4878:তেলর
# 4878:t̪elor
# Started 4879
# Started 4879 কেজি
# Ended 4879:কেজি
# 4879:keɟi
# Started 4880
# Started 4880 খদিন
# Ended 5041:থাইলিও
# 5041:t̪ʰa͡i̯li͡o̯
# Started 5042
# Started 5042 বুদ্ধি-টুদ্ধি
# Ended 4239:উইট্টিতে
# 4239:u͡i̯ttit̪e
# Started 4240
# Started 4240 মগজ
# Ended 4240:মগজ
# 4240:mɔgoɟ
# Started 4241
# Started 4241 ফাঁনি
# Ended 5441:খবি
# 5441:kʰobi
# Started 5442
# Started 5442 শুদ্ধ-বুদ্ধ
# Ended 5229:গেয়লে
# 5229:geʲle
# Started 5230
# Started 5230 যায়গই
# Ended 4880:খদিন
# 4880:kʰod̪in
# Started 4881
# Started 4881 মোমবাত্তি
# Ended 4052:খট্যা
# 4052:kʰotta
# Started 4053
# Started 4053 সাহেব
# Ended 4053:সাহেব
# 4053:ʃaheb
# Started 4054
# Started 4054 বাবুর
# Ended 4054:বাবুর
# 4054:babur
# Started 4055
# Started 4055 বৈঠকখানা
# Ended 4055:বৈঠকখানা
# 4055:bo͡i̯tʰokkʰana
# Started 4056
# Started 4056 কথা
# Ended 4056:কথা
# 4056:kɔt̪ʰa
# Started 4057
# Started 4057 বলতেছি
# Ended 5648:গেছিলি
# 5648:gecʰili
# Started 5649
# Started 5649 কালাইম্যারে
# Ended 4437:এক্কেনা
# 4437:ækkena
# Started 4438
# Started 4438 এহতেল্লেই
# Ended 4241:ফাঁনি
# 4241:pʰãni
# Started 4242
# Started 4242 গেইয়্যিগুই
# Ended 5849:দিবুয়েনে
# 5849:d̪ibuʲene
# Started 5850
# Started 5850 টেঁয়াগুন
# Ended 4633:কিছুক্কণ
# 4633:kicʰukkon
# Started 4634
# Started 4634 থাকো
# Ended 4634:থাকো
# 4634:t̪ʰako
# Started 4635
# Started 4635 ইফতারি
# Ended 4635:ইফতারি
# 4635:ipʰot̪ari
# Started 4636
# Started 4636 ফইল্যের
# Ended 5230:যায়গই
# 5230:ɟaʲgi
# Started 5231
# Started 5231 বাফেও
# Ended 4057:বলতেছি
# 4057:bolt̪ecʰi
# Started 4058
# Started 4058 এক্সেস
# Ended 5442:শুদ্ধ-বুদ্ধ
# 5442:ʃud̪d̪ʱo-bud̪d̪ʱo
# Started 5443
# Started 5443 নেক্সট
# Ended 5443:নেক্সট
# 5443:nekst
# Started 5444
# Started 5444 নেক্সটর
# Ended 5042:বুদ্ধি-টুদ্ধি
# 5042:bud̪d̪ʱi-tud̪d̪ʱi
# Started 5043
# Started 5043 গরিততারিবু
# Ended 4881:মোমবাত্তি
# 4881:mombat̪t̪i
# Started 4882
# Started 4882 লাম্বা
# Ended 4882:লাম্বা
# 4882:lamba
# Started 4883
# Started 4883 গ্লাস
# Ended 4883:গ্লাস
# 4883:glas
# Started 4884
# Started 4884 খওন
# Ended 5231:বাফেও
# 5231:bapʰe͡o̯
# Started 5232
# Started 5232 বাইরত
# Ended 4438:এহতেল্লেই
# 4438:eht̪elle͡i̯
# Started 4439
# Started 4439 ড্যাফোডিলত
# Ended 4636:ফইল্যের
# 4636:pʰɔ͡i̯ller
# Started 4637
# Started 4637 তোরতুন
# Ended 5850:টেঁয়াগুন
# 5850:tẽʲagun
# Started 5851
# Started 5851 ফাটায়
# Ended 5851:ফাটায়
# 5851:pʰataʲ
# Started 5852
# Started 5852 যখাতর
# Ended 5649:কালাইম্যারে
# 5649:kala͡i̯mkare
# Started 5650
# Started 5650 কাপ্তাই
# Ended 5650:কাপ্তাই
# 5650:kapt̪a͡i̯
# Started 5651
# Started 5651 সাইয়েইম্মা
# Ended 4884:খওন
# 4884:kʰɔ͡o̯n
# Started 4885
# Started 4885 সিন্তি
# Ended 4058:এক্সেস
# 4058:ekses
# Started 4059
# Started 4059 পতেঙ্গার
# Ended 4242:গেইয়্যিগুই
# 4242:ge͡i̯kigu͡i̯
# Started 4243
# Started 4243 আঁরঅত
# Ended 5444:নেক্সটর
# 5444:nekstor
# Started 5445
# Started 5445 চুদি
# Ended 5445:চুদি
# 5445:cud̪i
# Started 5446
# Started 5446 বাবু
# Ended 5446:বাবু
# 5446:babu
# Started 5447
# Started 5447 বলিবি
# Ended 5232:বাইরত
# 5232:ba͡i̯rɔt̪o
# Started 5233
# Started 5233 বোইনেরও
# Ended 5852:যখাতর
# 5852:ɟɔkʰat̪ɔr
# Started 5853
# Started 5853 গোশশা
# Ended 4637:তোরতুন
# 4637:t̪ort̪un
# Started 4638
# Started 4638 যিবে
# Ended 4243:আঁরঅত
# 4243:ãrɔt̪o
# Started 4244
# Started 4244 চিল্লেদ্দে
# Ended 4885:সিন্তি
# 4885:ʃint̪i
# Started 4886
# Started 4886 আনিবের
# Ended 5043:গরিততারিবু
# 5043:gorit̪ɔt̪aribu
# Started 5044
# Started 5044 আব্বাও
# Ended 5447:বলিবি
# 5447:bolibi
# Started 5448
# Started 5448 মেয়েগুলো
# Ended 5448:মেয়েগুলো
# 5448:meʲegulo
# Started 5449
# Started 5449 জোস
# Ended 5449:জোস
# 5449:ɟoʃ
# Started 5450
# Started 5450 ছ্যাপ
# Ended 4059:পতেঙ্গার
# 4059:pɔt̪eŋgar
# Started 4060
# Started 4060 এদিকে
# Ended 4060:এদিকে
# 4060:ed̪ike
# Started 4061
# Started 4061 খোন্যো
# Ended 4439:ড্যাফোডিলত
# 4439:dæpʰodilɔt̪o
# Started 4440
# Started 4440 সফটওয়্যার
# Ended 4440:সফটওয়্যার
# 4440:ʃɔpʰɔtolær
# Started 4441
# Started 4441 ইঞ্জিনিয়ারিংর
# Ended 4638:যিবে
# 4638:ɟibe
# Started 4639
# Started 4639 আলুর
# Ended 4639:আলুর
# 4639:alur
# Started 4640
# Started 4640 চপ
# Ended 4640:চপ
# 4640:cɔp
# Started 4641
# Started 4641 আইননস
# Ended 5853:গোশশা
# 5853:goʃoʃa
# Started 5854
# Started 5854 লাইত্থাইয়্যে
# Ended 5651:সাইয়েইম্মা
# 5651:ʃa͡i̯ʲe͡i̯mma
# Started 5652
# Started 5652 মুড়ি
# Ended 5652:মুড়ি
# 5652:muɽi
# Started 5653
# Started 5653 আটকা
# Ended 5653:আটকা
# 5653:atka
# Started 5654
# Started 5654 মিড
# Ended 5654:মিড
# 5654:mid
# Started 5655
# Started 5655 বলদ
# Ended 5655:বলদ
# 5655:bɔld̪
# Started 5656
# Started 5656 চাল
# Ended 5656:চাল
# 5656:cal
# Started 5657
# Started 5657 কত
# Ended 5657:কত
# 5657:kɔt̪o
# Started 5658
# Started 5658 খেলতে
# Ended 5658:খেলতে
# 5658:kʰelt̪e
# Started 5659
# Started 5659 ঢুকবে
# Ended 5659:ঢুকবে
# 5659:dʱukbe
# Started 5660
# Started 5660 মাইরটা
# Ended 5660:মাইরটা
# 5660:ma͡i̯rta
# Started 5661
# Started 5661 পারলে
# Ended 5661:পারলে
# 5661:parle
# Started 5662
# Started 5662 দিলেও
# Ended 5662:দিলেও
# 5662:d̪ile͡o̯
# Started 5663
# Started 5663 অনিক্কা
# Ended 5233:বোইনেরও
# 5233:bo͡i̯nero
# Started 5234
# Started 5234 মাও
# Ended 5234:মাও
# 5234:ma͡o̯
# Started 5235
# Started 5235 এখেলা
# Ended 4886:আনিবের
# 4886:aniber
# Started 4887
# Started 4887 খাডি
# Ended 5450:ছ্যাপ
# 5450:cʰæp
# Started 5451
# Started 5451 আলারফুত
# Ended 5044:আব্বাও
# 5044:abba͡o̯
# Started 5045
# Started 5045 আইলু
# Ended 5045:আইলু
# 5045:a͡i̯lu
# Started 5046
# Started 5046 আব্বারে
# Ended 5046:আব্বারে
# 5046:abbare
# Started 5047
# Started 5047 ফরিবি
# Ended 4641:আইননস
# 4641:a͡i̯nonʃ
# Started 4642
# Started 4642 খাওয়া
# Ended 4642:খাওয়া
# 4642:kʰa͡o̯ʷa
# Started 4643
# Started 4643 আন্ডা
# Ended 4643:আন্ডা
# 4643:anda
# Started 4644
# Started 4644 আন্ডার
# Ended 4644:আন্ডার
# 4644:andar
# Started 4645
# Started 4645 ডইক্কে
# Ended 4061:খোন্যো
# 4061:kʰonno
# Started 4062
# Started 4062 দেখছি
# Ended 4062:দেখছি
# 4062:d̪ekʰcʰi
# Started 4063
# Started 4063 এটার
# Ended 4063:এটার
# 4063:etar
# Started 4064
# Started 4064 হবো
# Ended 4064:হবো
# 4064:hɔbo
# Started 4065
# Started 4065 রইবারেও
# Ended 5235:এখেলা
# 5235:ekʰæla
# Started 5236
# Started 5236 নেদারল্যান্ডও
# Ended 4244:চিল্লেদ্দে
# 4244:cilled̪d̪e
# Started 4245
# Started 4245 কিল্লেই
# Ended 4887:খাডি
# 4887:kʰadi
# Started 4888
# Started 4888 উডানর
# Ended 5663:অনিক্কা
# 5663:ɔnikka
# Started 5664
# Started 5664 সিবিচ
# Ended 5047:ফরিবি
# 5047:pʰoribi
# Started 5048
# Started 5048 যেখোনো
# Ended 5451:আলারফুত
# 5451:alarpʰut̪
# Started 5452
# Started 5452 টাকলা
# Ended 4645:ডইক্কে
# 4645:dikke
# Started 4646
# Started 4646 সঁইয়্যের
# Ended 5854:লাইত্থাইয়্যে
# 5854:la͡i̯t̪t̪ʰa͡i̯ʲt̪e
# Started 5855
# Started 5855 লেদাইয়্যের
# Ended 4065:রইবারেও
# 4065:u͡i̯bare͡o̯
# Started 4066
# Started 4066 বাইচ্চা
# Ended 4888:উডানর
# 4888:udanor
# Started 4889
# Started 4889 টাইমর
# Ended 4441:ইঞ্জিনিয়ারিংর
# 4441:inɟiniʲariŋr
# Started 4442
# Started 4442 সেমিস্টারত
# Ended 5664:সিবিচ
# 5664:ʃibic
# Started 5665
# Started 5665 বিকেলর
# Ended 4245:কিল্লেই
# 4245:kille͡i̯
# Started 4246
# Started 4246 থাহিন্ন
# Ended 5048:যেখোনো
# 5048:ɟekʰono
# Started 5049
# Started 5049 ফরিলেই
# Ended 5452:টাকলা
# 5452:takla
# Started 5453
# Started 5453 মাইয়াগিন
# Ended 4889:টাইমর
# 4889:ta͡i̯mɔr
# Started 4890
# Started 4890 দিলেয়না
# Ended 4646:সঁইয়্যের
# 4646:ʃɔ̃ikd̪er
# Started 4647
# Started 4647 অবা
# Ended 5665:বিকেলর
# 5665:bikelɔr
# Started 5666
# Started 5666 সুদাইবার
# Ended 5236:নেদারল্যান্ডও
# 5236:ned̪arlændo
# Started 5237
# Started 5237 ইন্ডিয়ার
# Ended 5237:ইন্ডিয়ার
# 5237:indiʲar
# Started 5238
# Started 5238 যাইবগই
# Ended 4066:বাইচ্চা
# 4066:ba͡i̯cca
# Started 4067
# Started 4067 হাহাহাহা
# Ended 4246:থাহিন্ন
# 4246:t̪ʰahinno
# Started 4247
# Started 4247 আঁজিয়ের
# Ended 5049:ফরিলেই
# 5049:pʰorile͡i̯
# Started 5050
# Started 5050 আইএল্টস
# Ended 4647:অবা
# 4647:ɔba
# Started 4648
# Started 4648 জিলাপি
# Ended 4648:জিলাপি
# 4648:ɟilapi
# Started 4649
# Started 4649 ফুরাইন্না
# Ended 5855:লেদাইয়্যের
# 5855:led̪a͡i̯ʲd̪er
# Started 5856
# Started 5856 ইয়ানত
# Ended 4442:সেমিস্টারত
# 4442:ʃemistarot̪o
# Started 4443
# Started 4443 কয়দিন
# Ended 4443:কয়দিন
# 4443:kɔʲd̪in
# Started 4444
# Started 4444 আল্লার
# Ended 4444:আল্লার
# 4444:allar
# Started 4445
# Started 4445 কইরলে
# Ended 5453:মাইয়াগিন
# 5453:ma͡i̯ʲagin
# Started 5454
# Started 5454 সাবাস
# Ended 4890:দিলেয়না
# 4890:d̪ileʲna
# Started 4891
# Started 4891 বাতাসে
# Ended 4891:বাতাসে
# 4891:bat̪aʃe
# Started 4892
# Started 4892 লরের
# Ended 5238:যাইবগই
# 5238:ɟa͡i̯bɔgi
# Started 5239
# Started 5239 সাপ্তাহ-দেড়
# Ended 5666:সুদাইবার
# 5666:ʃud̪a͡i̯bar
# Started 5667
# Started 5667 আইন্নুস
# Ended 4067:হাহাহাহা
# 4067:hahahaha
# Started 4068
# Started 4068 রইবারের
# Ended 5856:ইয়ানত
# 5856:iʲanɔt̪o
# Started 5857
# Started 5857 লেদা
# Ended 4445:কইরলে
# 4445:ko͡i̯rle
# Started 4446
# Started 4446 প্ল্যান
# Ended 4446:প্ল্যান
# 4446:plæn
# Started 4447
# Started 4447 এরপরে
# Ended 4447:এরপরে
# 4447:erpɔre
# Started 4448
# Started 4448 আপাতত
# Ended 4448:আপাতত
# 4448:apat̪ɔt̪o
# Started 4449
# Started 4449 স্যাটেল
# Ended 4247:আঁজিয়ের
# 4247:ãɟiʲer
# Started 4248
# Started 4248 রোজা
# Ended 4248:রোজা
# 4248:roɟa
# Started 4249
# Started 4249 টুমি
# Ended 5050:আইএল্টস
# 5050:a͡i̯eltoʃ
# Started 5051
# Started 5051 ফায়েল্টস
# Ended 5454:সাবাস
# 5454:ʃabaʃ
# Started 5455
# Started 5455 এয়লে
# Ended 4892:লরের
# 4892:lɔrer
# Started 4893
# Started 4893 আজোয়াইন্না
# Ended 4649:ফুরাইন্না
# 4649:pʰura͡i̯nna
# Started 4650
# Started 4650 দিনর
# Ended 5857:লেদা
# 5857:led̪a
# Started 5858
# Started 5858 দুদু
# Ended 5858:দুদু
# 5858:d̪ud̪u
# Started 5859
# Started 5859 ফটফটফট
# Ended 4249:টুমি
# 4249:tumi
# Started 4250
# Started 4250 ফঁইত্তে
# Ended 5455:এয়লে
# 5455:eʲle
# Started 5456
# Started 5456 উত্তরবঙ্গ
# Ended 5456:উত্তরবঙ্গ
# 5456:ut̪t̪ɔrbɔŋgo
# Started 5457
# Started 5457 টুত্তরবঙ্গর
# Ended 5667:আইন্নুস
# 5667:a͡i̯nnuʃ
# Started 5668
# Started 5668 আস্তা
# Ended 4068:রইবারের
# 4068:u͡i̯barer
# Started 4069
# Started 4069 আইসতে
# Ended 4650:দিনর
# 4650:d̪inr
# Started 4651
# Started 4651 জিনিসর
# Ended 4449:স্যাটেল
# 4449:sætel
# Started 4450
# Started 4450 আইএলটস
# Ended 5239:সাপ্তাহ-দেড়
# 5239:ʃapt̪aho-d̪eɽ
# Started 5240
# Started 5240 সাপ্তাহর
# Ended 5051:ফায়েল্টস
# 5051:pʰaʲeltɔʃ
# Started 5052
# Started 5052 টাইয়েল্টস
# Ended 5859:ফটফটফট
# 5859:pʰɔtpʰɔtpʰɔt
# Started 5860
# Started 5860 বউওরে
# Ended 4893:আজোয়াইন্না
# 4893:aɟoʷa͡i̯nna
# Started 4894
# Started 4894 বাআরদি
# Ended 5668:আস্তা
# 5668:ast̪a
# Started 5669
# Started 5669 শঅরে
# Ended 4250:ফঁইত্তে
# 4250:pʰɔ̃it̪t̪e
# Started 4251
# Started 4251 ভাতও
# Ended 4069:আইসতে
# 4069:a͡i̯ʃt̪e
# Started 4070
# Started 4070 রইবারর
# Ended 4450:আইএলটস
# 4450:a͡i̯eltʃ
# Started 4451
# Started 4451 করিয়ানে
# Ended 4651:জিনিসর
# 4651:ɟiniʃɔr
# Started 4652
# Started 4652 খডখডি
# Ended 5860:বউওরে
# 5860:bɔ͡u̯ore
# Started 5861
# Started 5861 ইউসুফ্যের
# Ended 5669:শঅরে
# 5669:ʃɔ͡o̯re
# Started 5670
# Started 5670 উডিয়্যেরে
# Ended 5240:সাপ্তাহর
# 5240:ʃapt̪ahor
# Started 5241
# Started 5241 ইন্ডিয়াত
# Ended 4251:ভাতও
# 4251:bʱat̪o
# Started 4252
# Started 4252 হাইত
# Ended 5457:টুত্তরবঙ্গর
# 5457:tut̪t̪orbɔŋgor
# Started 5458
# Started 5458 বাত্তা
# Ended 4894:বাআরদি
# 4894:ba͡a̯cʰod̪i
# Started 4895
# Started 4895 সাইলাম
# Ended 5052:টাইয়েল্টস
# 5052:ta͡i̯ʲeltɔʃ
# Started 5053
# Started 5053 টত্তি
# Ended 4070:রইবারর
# 4070:u͡i̯baror
# Started 4071
# Started 4071 শিওর
# Ended 4071:শিওর
# 4071:ʃi͡o̯r
# Started 4072
# Started 4072 আইসতা
# Ended 4652:খডখডি
# 4652:kʰɔdkʰdi
# Started 4653
# Started 4653 টাইপর
# Ended 4252:হাইত
# 4252:ha͡i̯t̪o
# Started 4253
# Started 4253 হনবতে
# Ended 4451:করিয়ানে
# 4451:koriʲane
# Started 4452
# Started 4452 মাস্টার্স
# Ended 4452:মাস্টার্স
# 4452:mastars
# Started 4453
# Started 4453 বাকিগান
# Ended 5458:বাত্তা
# 5458:bat̪t̪a
# Started 5459
# Started 5459 উনিয়েনা
# Ended 5053:টত্তি
# 5053:tɔt̪t̪i
# Started 5054
# Started 5054 ফরিক্কাও
# Ended 4895:সাইলাম
# 4895:sa͡i̯lam
# Started 4896
# Started 4896 ল্যাম্পো
# Ended 4072:আইসতা
# 4072:a͡i̯ʃɔt̪a
# Started 4073
# Started 4073 তোঁয়ারা৷
# Ended 4073:তোঁয়ারা৷
# 4073:t̪õʷara
# Started 4074
# Started 4074 সাপ্তাহ
# Ended 4653:টাইপর
# 4653:ta͡i̯pɔr
# Started 4654
# Started 4654 ঘ্রান
# Ended 5241:ইন্ডিয়াত
# 5241:indiʲat̪
# Started 5242
# Started 5242 ট্যুরর
# Ended 5861:ইউসুফ্যের
# 5861:i͡u̯ʃupʰɟer
# Started 5862
# Started 5862 ধুত্তেরি
# Ended 5670:উডিয়্যেরে
# 5670:udikkere
# Started 5671
# Started 5671 নামাজ-টামাজ
# Ended 4253:হনবতে
# 4253:hɔnobot̪e
# Started 4254
# Started 4254 হনরহমে
# Ended 4453:বাকিগান
# 4453:bakigan
# Started 4454
# Started 4454 বওত
# Ended 4654:ঘ্রান
# 4654:gʱran
# Started 4655
# Started 4655 ঝাঁঝাইল্ল্যে
# Ended 5459:উনিয়েনা
# 5459:uniʲena
# Started 5460
# Started 5460 ঢাকাইয়্যা
# Ended 5242:ট্যুরর
# 5242:turɔr
# Started 5243
# Started 5243 ঘুরিটুরি
# Ended 4074:সাপ্তাহ
# 4074:ʃapt̪aho
# Started 4075
# Started 4075 রবিবারে
# Ended 4075:রবিবারে
# 4075:robibare
# Started 4076
# Started 4076 রইবারে
# Ended 5054:ফরিক্কাও
# 5054:pʰorikka͡o̯
# Started 5055
# Started 5055 কানাডার
# Ended 5055:কানাডার
# 5055:kanadar
# Started 5056
# Started 5056 এম্বেসি
# Ended 4454:বওত
# 4454:bɔ͡o̯t̪o
# Started 4455
# Started 4455 কম্পলিকেশন্স
# Ended 4254:হনরহমে
# 4254:hɔnorɔhɔme
# Started 4255
# Started 4255 বিতিরের
# Ended 4896:ল্যাম্পো
# 4896:læmpo
# Started 4897
# Started 4897 জলাইলি
# Ended 5862:ধুত্তেরি
# 5862:d̪ʱut̪t̪eri
# Started 5863
# Started 5863 যিয়্যেন
# Ended 5671:নামাজ-টামাজ
# 5671:namaɟ-tamaɟ
# Started 5672
# Started 5672 আদায়
# Ended 5672:আদায়
# 5672:ad̪aʲ
# Started 5673
# Started 5673 ফরেয়েনে
# Ended 4076:রইবারে
# 4076:u͡i̯bare
# Started 4077
# Started 4077 এখানে
# Ended 4077:এখানে
# 4077:ekʰane
# Started 4078
# Started 4078 তারফরের
# Ended 4897:জলাইলি
# 4897:ɟɔla͡i̯li
# Started 4898
# Started 4898 আরিকেল
# Ended 5056:এম্বেসি
# 5056:embeʃi
# Started 5057
# Started 5057 টেম্বেসিত
# Ended 4255:বিতিরের
# 4255:bit̪irer
# Started 4256
# Started 4256 ফড়িয়েরে
# Ended 5243:ঘুরিটুরি
# 5243:gʱurituri
# Started 5244
# Started 5244 ঘুরনঘারনে
# Ended 5460:ঢাকাইয়্যা
# 5460:dʱaka͡i̯ʲla
# Started 5461
# Started 5461 রক্তের
# Ended 5461:রক্তের
# 5461:rɔkt̪er
# Started 5462
# Started 5462 মায়ের
# Ended 5462:মায়ের
# 5462:maʲer
# Started 5463
# Started 5463 আইতু
# Ended 5863:যিয়্যেন
# 5863:ɟikd̪en
# Started 5864
# Started 5864 বিসয়ানও
# Ended 4655:ঝাঁঝাইল্ল্যে
# 4655:ɟʱãɟʱa͡i̯llæ͡e̯
# Started 4656
# Started 4656 ঝাঝ
# Ended 5673:ফরেয়েনে
# 5673:pʰɔreʲene
# Started 5674
# Started 5674 আঁইডতে
# Ended 5463:আইতু
# 5463:a͡i̯t̪u
# Started 5464
# Started 5464 আব্বার
# Ended 5464:আব্বার
# 5464:abbar
# Started 5465
# Started 5465 আম্মার
# Ended 5465:আম্মার
# 5465:ammar
# Started 5466
# Started 5466 ভাষ
# Ended 4455:কম্পলিকেশন্স
# 4455:kɔmpolikeʃons
# Started 4456
# Started 4456 কিছুর
# Ended 4456:কিছুর
# 4456:kicʰur
# Started 4457
# Started 4457 প্রিপারেশন
# Ended 4457:প্রিপারেশন
# 4457:pripareʃon
# Started 4458
# Started 4458 প্রেশারত
# Ended 4656:ঝাঝ
# 4656:ɟʱaɟʱ
# Started 4657
# Started 4657 মিষ্টিও
# Ended 4898:আরিকেল
# 4898:arikel
# Started 4899
# Started 4899 আরতুন
# Ended 4078:তারফরের
# 4078:t̪arpʰɔrer
# Started 4079
# Started 4079 শুনো
# Ended 4079:শুনো
# 4079:ʃuno
# Started 4080
# Started 4080 রাহিমা
# Ended 4080:রাহিমা
# 4080:rahima
# Started 4081
# Started 4081 খাওয়াইতো
# Ended 4081:খাওয়াইতো
# 4081:kʰa͡o̯ʷa͡i̯t̪o
# Started 4082
# Started 4082 মিষ্টি
# Ended 4082:মিষ্টি
# 4082:miʃti
# Started 4083
# Started 4083 তরকারি
# Ended 4083:তরকারি
# 4083:t̪ɔrkari
# Started 4084
# Started 4084 খবার

# %%
# Fills the empty ones
subset1_1000=df.iloc[3000:6000]
for row in subset1_1000.itertuples():
  print(row.Index)
  # print(row[1])
  if pd.notna(row.ipa):
    continue
  print(row.sentence)
  data=call_api(row.sentence)
  # print(data["data"][0])
  if data:
    df.at[row.Index,"ipa"]=data["data"][0]
  else:
    print(row.Index)
    print(row.sentence)
    break
df.to_csv("withIPA.csv",index=False)

# %% [markdown]
# **TESTINS**
#
# ---

# %%
# test connection
def call_api (param):
    url = f"http://127.0.0.1:5000//transcribeBanglaTextToIpa?bangla_ipa={param}"
    response = requests.get (url, verify=False)
    if response.status_code == 200:
        return response.json()
    else:
        return None
data=call_api("আমার সোনার বাংলা।")
data["data"][0]
# Out:
# 'amar ʃonar baŋla।'

# %%
# Fills the empty ones
subset1_1000=df.iloc[20000:70000]
for row in subset1_1000.itertuples():
  # print(row.Index)
  # print(row[1])
  # if pd.notna(row.ipa):
  #   continue
  # print(row.word)
  data=call_api(row.word)
  # print(data["data"][0])
  if data:
    # df.at[row.Index,"ipa"]=data["data"][0]
    print(f"{row.Index}:{data['data'][0]}")
  else:
    print(row.Index)
    print(row.word)
    break
# df.to_csv("withIPA.csv",index=False)

# %%
multiprocessing.cpu_count()

# %%
print(pool.shutdown( cancel_futures=True))
df.to_csv(f"withIPA{start_pos}_{end}.csv",index=False)
# Out:
# None

# %%
# w0= pool.submit(subset_worker, subsets[0])
# w1=pool.submit(subset_worker, subsets[1])
# w2=pool.submit(subset_worker, subsets[2])
# w3=pool.submit(subset_worker, subsets[3])
# w4=pool.submit(subset_worker, subsets[4])
# w0.result()
# w1.result()
# w2.result()
# w3.result()
# w4.result()

# print(w0.cancel())
# print(w1.cancel())
# print(w2.cancel())
# print(w3.cancel())
# print(w4.cancel())

# %%
# not working
i=500
steps=100
end=1000
subsets=[]
while i<end:
  subsets.append(df.iloc[i:i+steps])
  i=i+steps
print(subsets)

threads=[]
for subset in subsets:
  threads.append(threading.Thread(target=subset_worker, daemon=True, args=(subset,)))
for thread in threads:
  thread.start();
  time.sleep(1)
for thread in threads:
  thread.join()
print("end")

# %% [markdown]
# Cleaning

# %%
# Unique word clearing
df=pd.read_csv("bangla_to_ipa_unique_clean2.csv")
df.drop_duplicates(subset=['bangla_token'], inplace=True)
print(len(df))
df.sort_values('bangla_token').to_csv("bangla_to_ipa_unique_clean.csv",index=False)
# Out:
# 58569

# %%
df=pd.read_csv("bangla_to_ipa_unique_clean2.csv")
remove=[]
for row in df.itertuples():
  if len(row.bangla_token)>2 and row.bangla_token[-2]=="!":
    # print(row.bangla_token[1:])

    for i in range(1,110,1):
      if df.at[row.Index-i,"bangla_token"]==row.bangla_token[:-2]:
        print(row.Index)
        print(row.bangla_token)
        # remove that row
        remove.append(row.Index)
        break

df.drop(remove, inplace=True)
print(len(remove))
# Out:
# 0

# %%
# check whole dataset
df=pd.read_csv("bangla_to_ipa_unique_clean2.csv")
remove=[]
for row in df.itertuples():
  if row.bangla_token[:-1]=="?":
    # if contains in the whole dataset
    for i in range(len(df)):
      if df.at[i,"bangla_token"]==row.bangla_token[:-1]:
        print(row.Index)
        print(i)
        print(row.bangla_token)
        # remove that row
        remove.append(row.Index)
        break
df.drop(remove, inplace=True)

# %%
df.to_csv("bangla_to_ipa_unique_clean2.csv",index=False)

# %%
a="bangla_to_ipa_unique_clean"
print(a[1:])
# Out:
# angla_to_ipa_unique_clean
