# %%
import pandas as pd
import glob

df=pd.read_csv("combine.csv")
# read all csv files in the folder using glob and pandas in a lambda function
dfs=[pd.read_csv(f) for f in glob.glob("*.csv")]
print(len(dfs))
# subset=df.iloc[0:106500]
for row in df.itertuples():
  if pd.isna(row.ipa_narshingdi):
    print(row.Index/10)
    for other in dfs:
      if pd.notna(other.at[row.Index,"ipa_narshingdi"]):
        df.at[row.Index,"ipa_narshingdi"]=other.at[row.Index,"ipa_narshingdi"]
        break
df.to_csv("combine.csv",index=False)
# Out:
# 8
# 100.0
# 100.1
# 100.2
# 100.3
# 100.4
# 100.5
# 100.6
# 100.7
# 100.8
# 100.9
# 101.0
# 101.1
# 101.2
# 101.3
# 101.4
# 101.5
# 101.6
# 101.7
# 101.8
# 101.9
# 102.0
# 102.1
# 102.2
# 102.3
# 102.4
# 102.5
# 102.6
# 102.7
# 102.8
# 102.9
# 103.0
# 103.1
# 103.2
# 103.3
# 103.4
# 103.5
# 103.6
# 103.7
# 103.8
# 103.9
# 104.0
# 104.1
# 104.2
# 104.3
# 104.4
# 104.5
# 104.6
# 104.7
# 104.8
# 104.9
# 105.0
# 105.1
# 105.2
# 105.3
# 105.4
# 105.5
# 105.6
# 105.7
# 105.8
# 105.9
# 106.0
# 106.1
# 106.2
# 106.3
# 106.4
# 106.5
# 106.6
# 106.7
# 106.8
# 106.9
# 107.0
# 107.1
# 107.2
# 107.3
# 107.4
# 107.5
# 107.6
# 107.7
# 107.8
# 107.9
# 108.0
# 108.1
# 108.2
# 108.3
# 108.4
# 108.5
# 108.6
# 108.7
# 108.8
# 108.9
# 109.0
# 109.1
# 109.2
# 109.3
# 109.4
# 109.5
# 109.6
# 109.7
# 109.8
# 109.9
# 110.0
# 110.1
# 110.2
# 110.3
# 110.4
# 110.5
# 110.6
# 110.7
# 110.8
# 110.9
# 111.0
# 111.1
# 111.2
# 111.3
# 111.4
# 111.5
# 111.6
# 111.7
# 111.8
# 111.9
# 112.0
# 112.1
# 112.2
# 112.3
# ...

# %%
import pandas as pd
import glob

df=pd.read_csv("combine.csv")
# read all csv files in the folder using glob and pandas in a lambda function
dfs=[pd.read_csv(f) for f in glob.glob("*.csv")]
print(len(dfs))
# subset=df.iloc[0:106500]
for row in df.itertuples():
  if "__##__" not in row.validated_ipa :
    df.at[row.Index,"done"]=None
    print(row.Index/10)
    for other in dfs:
      if "__##__" in other.at[row.Index,"validated_ipa"]:
        df.at[row.Index,"validated_ipa"]=other.at[row.Index,"validated_ipa"]
        df.at[row.Index,"done"]="OK"

        break
df.to_csv("combine.csv",index=False)
# Out:
# 3
# 1.4
# 6.2
# 138.4
# 165.9
# 266.7
# 286.8
# 377.5
# 406.7
# 639.9
# 647.7
# 652.6
# 836.2
# 933.5
# 1671.3
# 2107.6
# 2512.2
# 2860.8
# 3814.7
# 4771.3
# 4811.5
# 4971.9
# 4987.2
# 4990.3
# 5003.0
# 5107.7
# 5143.4
# 5178.2
# 5270.3
# 5277.4
# 5484.8
# 5711.9
# 5712.0
# 5712.1
# 5712.2
# 5712.3
# 5712.4
# 5712.5
# 5951.9
# 6183.0
# 6192.2
# 6215.0
# 6374.5
# 6545.0
# 6620.0
# 6746.7
# 6855.3
# 6855.5
# 6865.9
# 7312.7
# 7343.0
# 7354.0
# 7373.5
# 7378.3
# 7434.4
# 7511.3
# 7543.1
# 7895.3
# 8811.0
# 9014.4
# 9083.3
# 9083.4
# 9083.5
# 9359.8
# 9392.2
# 9392.9
# 9967.5

# %%
df=pd.read_csv("combine.csv")
for row in df.itertuples():
  if "__##__" not in row.validated_ipa :
    print(row.Index/10)
    df.at[row.Index,"done"]=None
  else:
    df.at[row.Index,"done"]="OK"
df.to_csv("combine.csv",index=False)
# Out:
# 1.4
# 6.2
# 138.4
# 165.9
# 266.7
# 286.8
# 377.5
# 406.7
# 639.9
# 647.7
# 652.6
# 836.2
# 933.5
# 1671.3
# 2107.6
# 2512.2
# 2860.8
# 3814.7
# 4771.3
# 4811.5
# 4971.9
# 4987.2
# 4990.3
# 5003.0
# 5107.7
# 5143.4
# 5178.2
# 5270.3
# 5277.4
# 5484.8
# 5711.9
# 5712.0
# 5712.1
# 5712.2
# 5712.3
# 5712.4
# 5712.5
# 5951.9
# 6183.0
# 6192.2
# 6215.0
# 6374.5
# 6545.0
# 6620.0
# 6746.7
# 6855.3
# 6855.5
# 6865.9
# 7312.7
# 7343.0
# 7354.0
# 7373.5
# 7378.3
# 7434.4
# 7511.3
# 7543.1
# 7895.3
# 8811.0
# 9014.4
# 9083.3
# 9083.4
# 9083.5
# 9359.8
# 9392.2
# 9392.9
# 9967.5

# %%
df=pd.read_csv("combine.csv")
for row in df.itertuples():
  if pd.isna(row.done) :
    print(row.Index/10)
# Out:
# 1.4
# 6.2
# 138.4
# 165.9
# 266.7
# 286.8
# 377.5
# 406.7
# 639.9
# 647.7
# 652.6
# 836.2
# 933.5
# 1671.3
# 2107.6
# 2512.2
# 2860.8
# 3814.7
# 4771.3
# 4811.5
# 4971.9
# 4987.2
# 4990.3
# 5003.0
# 5107.7
# 5143.4
# 5178.2
# 5270.3
# 5277.4
# 5484.8
# 5711.9
# 5712.0
# 5712.1
# 5712.2
# 5712.3
# 5712.4
# 5712.5
# 5951.9
# 6183.0
# 6192.2
# 6215.0
# 6374.5
# 6545.0
# 6620.0
# 6746.7
# 6855.3
# 6855.5
# 6865.9
# 7312.7
# 7343.0
# 7354.0
# 7373.5
# 7378.3
# 7434.4
# 7511.3
# 7543.1
# 7895.3
# 8811.0
# 9014.4
# 9083.3
# 9083.4
# 9083.5
# 9359.8
# 9392.2
# 9392.9
# 9967.5
